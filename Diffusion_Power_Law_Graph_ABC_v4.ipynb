# %% [markdown]
# ### A - Random Diffusion Behavior
# ### B - Algo1 Diffusion Behavior
# ### C - Algo1 Diffusion Behavior

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import networkx as nx
import os
#import nxviz as nv
os.getcwd()
# Out:
# 'C:\\Users\\sumith.singh\\A_SUBEX'

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# # Graph Generation

# %%
n =  100 # number of nodes
nodes = list(range(1,n))

# %%
while True:  
    s=[]
    while len(s)<n:
        nextval = int(nx.utils.powerlaw_sequence(1, 2.5)[0]) #100 nodes, power-law exponent 2.5
        if nextval!=0:
            s.append(nextval)
    if sum(s)%2 == 0:
        break
G = nx.configuration_model(s)
G=nx.Graph(G) # remove parallel edges
G.remove_edges_from(G.selfloop_edges())

# %%
nx.draw(G)
plt.show()
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos)
plt.show()

# %%
#list(G.nodes())

# %%
# Graph Properties
print('Edges -- ')
print(G.edges())
print('Neighbors--')
print(G.neighbors(2))
print('Degree Centrality')
print(nx.degree_centrality(G))
#print('Graph')
#print(G)
# Out:
# Edges --
# [(0, 23), (1, 68), (2, 51), (3, 5), (3, 92), (3, 10), (3, 47), (3, 21), (3, 51), (3, 8), (4, 12), (4, 99), (4, 86), (6, 92), (7, 83), (9, 29), (9, 51), (9, 49), (9, 78), (9, 82), (9, 80), (9, 66), (11, 42), (12, 97), (12, 50), (13, 44), (13, 78), (13, 83), (14, 24), (15, 88), (15, 40), (16, 84), (17, 34), (18, 39), (19, 30), (19, 60), (20, 21), (21, 98), (21, 51), (21, 28), (22, 35), (25, 42), (26, 92), (27, 77), (29, 88), (30, 82), (31, 94), (32, 96), (33, 83), (34, 78), (36, 55), (37, 51), (37, 69), (38, 83), (39, 77), (39, 74), (41, 75), (42, 71), (42, 93), (43, 72), (45, 54), (46, 70), (46, 95), (46, 89), (48, 77), (50, 51), (51, 87), (51, 78), (51, 76), (51, 64), (52, 99), (53, 83), (54, 92), (56, 62), (57, 58), (58, 67), (59, 61), (62, 86), (63, 92), (63, 78), (65, 73), (67, 75), (77, 90), (77, 79), (78, 91), (79, 85), (81, 83), (88, 92), (90, 92)]
# Neighbors--
# [51]
# Degree Centrality
# {0: 0.010101010101010102, 1: 0.010101010101010102, 2: 0.010101010101010102, 3: 0.07070707070707072, 4: 0.030303030303030304, 5: 0.010101010101010102, 6: 0.010101010101010102, 7: 0.010101010101010102, 8: 0.010101010101010102, 9: 0.07070707070707072, 10: 0.010101010101010102, 11: 0.010101010101010102, 12: 0.030303030303030304, 13: 0.030303030303030304, 14: 0.010101010101010102, 15: 0.020202020202020204, 16: 0.010101010101010102, 17: 0.010101010101010102, 18: 0.010101010101010102, 19: 0.020202020202020204, 20: 0.010101010101010102, 21: 0.05050505050505051, 22: 0.010101010101010102, 23: 0.010101010101010102, 24: 0.010101010101010102, 25: 0.010101010101010102, 26: 0.010101010101010102, 27: 0.010101010101010102, 28: 0.010101010101010102, 29: 0.020202020202020204, 30: 0.020202020202020204, 31: 0.010101010101010102, 32: 0.010101010101010102, 33: 0.010101010101010102, 34: 0.020202020202020204, 35: 0.010101010101010102, 36: 0.010101010101010102, 37: 0.020202020202020204, 38: 0.010101010101010102, 39: 0.030303030303030304, 40: 0.010101010101010102, 41: 0.010101010101010102, 42: 0.04040404040404041, 43: 0.010101010101010102, 44: 0.010101010101010102, 45: 0.010101010101010102, 46: 0.030303030303030304, 47: 0.010101010101010102, 48: 0.010101010101010102, 49: 0.010101010101010102, 50: 0.020202020202020204, 51: 0.10101010101010102, 52: 0.010101010101010102, 53: 0.010101010101010102, 54: 0.020202020202020204, 55: 0.010101010101010102, 56: 0.010101010101010102, 57: 0.010101010101010102, 58: 0.020202020202020204, 59: 0.010101010101010102, 60: 0.010101010101010102, 61: 0.010101010101010102, 62: 0.020202020202020204, 63: 0.020202020202020204, 64: 0.010101010101010102, 65: 0.010101010101010102, 66: 0.010101010101010102, 67: 0.020202020202020204, 68: 0.010101010101010102, 69: 0.010101010101010102, 70: 0.010101010101010102, 71: 0.010101010101010102, 72: 0.010101010101010102, 73: 0.010101010101010102, 74: 0.010101010101010102, 75: 0.020202020202020204, 76: 0.010101010101010102, 77: 0.05050505050505051, 78: 0.06060606060606061, 79: 0.020202020202020204, 80: 0.010101010101010102, 81: 0.010101010101010102, 82: 0.020202020202020204, 83: 0.06060606060606061, 84: 0.010101010101010102, 85: 0.010101010101010102, 86: 0.020202020202020204, 87: 0.010101010101010102, 88: 0.030303030303030304, 89: 0.010101010101010102, 90: 0.020202020202020204, 91: 0.010101010101010102, 92: 0.07070707070707072, 93: 0.010101010101010102, 94: 0.010101010101010102, 95: 0.010101010101010102, 96: 0.010101010101010102, 97: 0.010101010101010102, 98: 0.010101010101010102, 99: 0.020202020202020204}

# %%
max_nbrs = 0
max_node = 0
for element in G.nodes():
    #print(element, len(G.neighbors(element)) )
    if len(G.neighbors(element)) > max_nbrs:
        max_nbrs = len(G.neighbors(element))
        max_node = element
print("The node with maximum number of neighbor is: ", max_node)
print("The neighbors are: ", G.neighbors(max_node))
print("The number of neighbors is: ", len(G.neighbors(max_node)))
# Out:
# The node with maximum number of neighbor is:  51
# The neighbors are:  [2, 3, 9, 21, 37, 50, 87, 78, 76, 64]
# The number of neighbors is:  10

# %%
nx.set_node_attributes(G,'degree_cent',nx.degree_centrality(G))

# %%
degrees = [len(G.neighbors(n)) for n in G.nodes()]
deg_cent = nx.degree_centrality(G)
plt.hist(list(deg_cent.values()))
plt.show()

# %%
plt.hist(degrees)
plt.show()

# %%
plt.scatter(degrees, list(deg_cent.values()))
plt.show()

# %%
from random import randrange
from datetime import timedelta
import datetime

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
d1A = datetime.datetime.strptime('1/1/2016 1:30 PM', '%m/%d/%Y %I:%M %p')
d2A = datetime.datetime.strptime('1/13/2016 4:50 AM', '%m/%d/%Y %I:%M %p')
d1B = datetime.datetime.strptime('3/1/2017 1:30 PM', '%m/%d/%Y %I:%M %p')
d2B = datetime.datetime.strptime('3/13/2017 4:50 AM', '%m/%d/%Y %I:%M %p')
d1C = datetime.datetime.strptime('5/1/2018 1:30 PM', '%m/%d/%Y %I:%M %p')
d2C = datetime.datetime.strptime('5/13/2018 4:50 AM', '%m/%d/%Y %I:%M %p')
print(random_date(d1A, d2A))
# Out:
# 2016-01-07 20:26:13

# %%
len(nodes)
# Out:
# 99

# %%
nodes[98]
# Out:
# 99

# %% [markdown]
# # First DF Creation

# %%
traits = ['A','B','C']
cols = ['Sequence','Behavior', 'Node', 'Time', 'Prob']
df2 = pd.DataFrame(columns=cols, index=range((len(traits)*len(nodes))))   # 100 need not be put in a afile. It will be modified once we have an external data source
for a in range(len(traits)*len(nodes)):
    df2.loc[a].Sequence = 1
    df2.loc[a].Behavior = 'A'
    df2.loc[a].Node = 5
    df2.loc[a].Time = datetime.datetime.strptime('1/1/2018 1:30 PM', '%m/%d/%Y %I:%M %p')
    df2.loc[a].Prob = 0.00001
#df2

# %%
k = 0
for i in traits:
    k = k + 1
    #print("Outer")
    for j in nodes:
        #Behav_Time = [random_date(d1,d2) for k in range(len(nodes)+1)]
        Behav_Prob = [np.random.random() for i in range(len(nodes)+1)]
        #bhv_prb = np.random.random()
        order = ((k-1)*len(nodes)+j)
        a = order - 1
        #data = dict(zip(Behav_Time[j],round(Behav_Prob[j],2)))
        df2.loc[a].Sequence = a+1
        df2.loc[a].Behavior = i
        df2.loc[a].Node = j
        if i == 'A' :
            df2.loc[a].Time = random_date(d1A,d2A)
        elif i == 'B' :
            df2.loc[a].Time = random_date(d1B,d2B)
        else :
            df2.loc[a].Time = random_date(d1C,d2C)
        df2.loc[a].Prob = round(Behav_Prob[j],2)
        #print(order,i,j,Behav_Time[j],round(Behav_Prob[j],2) )
       # new_df[order-1] = ['A', 1, '20-06-2018', 0.32]
print(order)
# Out:
# 297

# %%
df2.sample(5)
# Out:
#     Sequence Behavior Node                 Time  Prob
# 224      225        C   27  2018-05-13 01:15:00  0.44
# 236      237        C   39  2018-05-12 11:37:22  0.72
# 234      235        C   37  2018-05-05 22:00:25  0.01
# 274      275        C   77  2018-05-03 16:45:42  0.99
# 12        13        A   13  2016-01-11 17:47:51  0.69

# %%
df2.Behavior.unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df2 = df2.drop(df2[df2.Behavior != 'A'].index)
df2.sample(5)
# Out:
#    Sequence Behavior Node                 Time  Prob
# 57       58        A   58  2016-01-07 19:53:24  0.53
# 62       63        A   63  2016-01-10 22:28:30  0.46
# 12       13        A   13  2016-01-11 17:47:51  0.69
# 69       70        A   70  2016-01-06 17:55:48  0.18
# 58       59        A   59  2016-01-06 14:58:13  0.16

# %%
df2.Behavior.unique()
# Out:
# array(['A'], dtype=object)

# %%
df2 = df2.drop(df2[df2.Prob < 0.5].index)

# %%
range(df2.shape[1])
df2.shape
# Out:
# (55, 5)

# %%
df2 = df2.drop('Sequence',axis=1)
df2 = df2.drop('Prob',axis=1)

# %%
df2.reset_index(inplace=True)
df2.drop(columns='index', inplace=True)
df2.head()
# Out:
#   Behavior Node                 Time
# 0        A    1  2016-01-03 17:26:07
# 1        A    3  2016-01-11 03:28:10
# 2        A    4  2016-01-06 02:44:17
# 3        A    5  2016-01-12 22:05:51
# 4        A    6  2016-01-03 21:54:07

# %%
#df2.dtypes

# %%
df3 = df2.groupby('Behavior')['Time'].min()
df3
# Out:
# Behavior
# A   2016-01-01 16:26:01
# Name: Time, dtype: datetime64[ns]

# %%
print("A:" + str(df3['A']))
#print('B:' + str(df3['B']))
#print('C:' + str(df3['C']))
# Out:
# A:2016-01-01 16:26:01

# %%
def get_min(df):
    if df['Behavior'] == 'A' :
        return df3['A']
    elif df['Behavior'] == 'B' :
        return df3['B']
    else :
        return df3['C']

# %%
df2['min'] = df2.apply(get_min, axis=1)
df2['Time'] =  pd.to_datetime(df2['Time'], format='%m/%d/%Y %I:%M %p')
print(df2.info())
df2.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 4 columns):
# Behavior    55 non-null object
# Node        55 non-null object
# Time        55 non-null datetime64[ns]
# min         55 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 1.8+ KB
# None
#    Behavior Node                Time                 min
# 52        A   96 2016-01-12 22:47:43 2016-01-01 16:26:01
# 21        A   36 2016-01-05 19:06:21 2016-01-01 16:26:01
# 31        A   52 2016-01-03 11:26:16 2016-01-01 16:26:01
# 2         A    4 2016-01-06 02:44:17 2016-01-01 16:26:01
# 7         A   13 2016-01-11 17:47:51 2016-01-01 16:26:01

# %% [markdown]
# # Lag Creation

# %%
#df2['Time'] =  pd.to_datetime(df2['Time'], format='%d%b%Y:%H:%M:%S.%f')
df2['lag'] = (df2['Time'] - df2['min'])
df2['lag2'] = 0
df2.reset_index(inplace=True)
df2.drop(columns='index', inplace=True)
for i in range(len(df2)):
    df2.lag2[i] = (df2.loc[i].lag.days)
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# # Neighbors & Degree Centrality Creation

# %%
df2['Neighbors'] = ''
df2['Deg_Cntrlty'] = 0.0
for i in range(len(df2)):
    df2.Neighbors[i] = list(G.neighbors(df2.loc[i].Node))
    df2.Deg_Cntrlty[i] = nx.degree_centrality(G)[df2.loc[i].Node]
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#nx.degree_centrality(G)
#nx.degree_centrality(G)[4]

# %%
#df2.drop(columns = ['level_0','index'], inplace=True)

# %%
df2.head()
# Out:
#   Behavior Node                Time                 min              lag  \
# 0        A    1 2016-01-03 17:26:07 2016-01-01 16:26:01  2 days 01:00:06
# 1        A    3 2016-01-11 03:28:10 2016-01-01 16:26:01  9 days 11:02:09
# 2        A    4 2016-01-06 02:44:17 2016-01-01 16:26:01  4 days 10:18:16
# 3        A    5 2016-01-12 22:05:51 2016-01-01 16:26:01 11 days 05:39:50
# 4        A    6 2016-01-03 21:54:07 2016-01-01 16:26:01  2 days 05:28:06
#
#    lag2                   Neighbors  Deg_Cntrlty
# 0     2                        [68]     0.010101
# 1     9  [5, 92, 10, 47, 21, 51, 8]     0.070707
# 2     4                [12, 99, 86]     0.030303
# 3    11                         [3]     0.010101
# 4     2                        [92]     0.010101

# %% [markdown]
# # Friends, Relations & Influencer Score

# %%
df2['relation']=''
df2['ratio']=0.0
df2['inflncr_scr'] = 0
df2['high_nbrs'] = ''

# %%
def realtion(dfx):
    b=[]
    for j in range(len(dfx)):
        i=0
        a=[]
        for i in range(len(dfx.Neighbors[j])):
            #print(dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values,"\t",dfx.lag2[dfx.Node==dfx.Node[j]].values)
            if dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values<dfx.lag2[dfx.Node==dfx.Node[j]].values:
                a.append(dfx.Neighbors[j][i])
        dfx['relation'][j]=a
        if len(dfx.Neighbors[j]) == 0:
            dfx['ratio'][j] = 0
        else:
            dfx['ratio'][j] = len(a)/len(dfx.Neighbors[j])
    return dfx

# %%
df2[df2.Deg_Cntrlty > 0.01].sample(5)
# Out:
#    Behavior Node                Time                 min             lag  \
# 11        A   20 2016-01-11 06:16:39 2016-01-01 16:26:01 9 days 13:50:38
# 44        A   85 2016-01-06 23:06:30 2016-01-01 16:26:01 5 days 06:40:29
# 34        A   60 2016-01-05 08:08:58 2016-01-01 16:26:01 3 days 15:42:57
# 13        A   24 2016-01-02 15:47:03 2016-01-01 16:26:01 0 days 23:21:02
# 14        A   25 2016-01-06 09:43:03 2016-01-01 16:26:01 4 days 17:17:02
#
#     lag2 Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 11     9      [21]     0.010101             0.0            0
# 44     5      [79]     0.010101             0.0            0
# 34     3      [19]     0.010101             0.0            0
# 13     0      [14]     0.010101             0.0            0
# 14     4      [42]     0.010101             0.0            0

# %%
def high_nbrs(dfx):
    for j in range(len(dfx)):
        str_nbrs = []
        max_nbr = 0
        max_deg = 0
        for i in G.neighbors(dfx.loc[j].Node):
            #print(i)
            if nx.degree_centrality(G)[i] >= max_deg:
                #print(nx.degree_centrality(G)[i])
                if nx.degree_centrality(G)[i] > max_deg:
                    str_nbrs = []
                    str_nbrs.append(i)
                    max_deg = nx.degree_centrality(G)[i]
                    max_nbr = i
                else:
                    str_nbrs.append(i)
        dfx['high_nbrs'][j] = str_nbrs
    return dfx

# %%
df2A = df2[df2.Behavior=='A']
#df2B = df2[df2.Behavior=='B']
#df2C = df2[df2.Behavior=='C']

# %%
df2A.reset_index(inplace=True)
df2A.drop(columns='index', inplace=True)
#df2B.reset_index(inplace=True)
#df2B.drop(columns='index', inplace=True)
#df2C.reset_index(inplace=True)
#df2C.drop(columns='index', inplace=True)

# %%
#df2A = realtion(df2A)
#df2B = realtion(df2B)
#df2C = realtion(df2C)
df2A.sample(5)
# Out:
#    Behavior Node                Time                 min              lag  \
# 43        A   82 2016-01-03 01:25:39 2016-01-01 16:26:01  1 days 08:59:38
# 3         A    5 2016-01-12 22:05:51 2016-01-01 16:26:01 11 days 05:39:50
# 54        A   99 2016-01-03 16:42:11 2016-01-01 16:26:01  2 days 00:16:10
# 19        A   32 2016-01-12 11:39:47 2016-01-01 16:26:01 10 days 19:13:46
# 28        A   47 2016-01-08 08:28:26 2016-01-01 16:26:01  6 days 16:02:25
#
#     lag2 Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 43     1   [9, 30]     0.020202             0.0            0
# 3     11       [3]     0.010101             0.0            0
# 54     2   [4, 52]     0.020202             0.0            0
# 19    10      [96]     0.010101             0.0            0
# 28     6       [3]     0.010101             0.0            0

# %%
df2A = high_nbrs(df2A)
df2A.sample(5)
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Behavior Node                Time                 min              lag  \
# 44        A   85 2016-01-06 23:06:30 2016-01-01 16:26:01  5 days 06:40:29
# 29        A   50 2016-01-11 17:31:17 2016-01-01 16:26:01 10 days 01:05:16
# 39        A   74 2016-01-06 15:29:36 2016-01-01 16:26:01  4 days 23:03:35
# 33        A   58 2016-01-07 19:53:24 2016-01-01 16:26:01  6 days 03:27:23
# 51        A   95 2016-01-02 23:13:02 2016-01-01 16:26:01  1 days 06:47:01
#
#     lag2 Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 44     5      [79]     0.010101             0.0            0      [79]
# 29    10  [12, 51]     0.020202             0.0            0      [51]
# 39     4      [39]     0.010101             0.0            0      [39]
# 33     6  [57, 67]     0.020202             0.0            0      [67]
# 51     1      [46]     0.010101             0.0            0      [46]

# %%
cliques = nx.find_cliques(G)
list(cliques)
nx.number_of_cliques(G)
nx.number_of_cliques(G, nodes = 12)
# Out:
# 3

# %% [markdown]
#  # Alternate Algorithm for Behavior Generation

# %%
def realtion(dfx):
    b=[]
    for j in range(len(dfx)):
        i=0
        a=[]
        for i in range(len(dfx.Nbrs[j])):
            #print(dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values,"\t",dfx.lag2[dfx.Node==dfx.Node[j]].values)
            if dfx.Day[dfx.Node==dfx.Nbrs[j][i]].values<dfx.Day[dfx.Node==dfx.Node[j]].values:
                a.append(dfx.Nbrs[j][i])
        dfx['Nbrs_Dffsed'][j]=a
        dfx['Num_Nbrs_Dffsd'][j]=len(a)
        if len(dfx.Nbrs[j]) == 0:
            dfx['ratio'][j] = 0
        else:
            dfx['ratio'][j] = len(a)/len(dfx.Nbrs[j])
    return dfx

# %%
def high_diffsd(dfx):
    y = 0
    for j in range(len(dfx)):
        i = 0
        y = 0
        for i in range(len(dfx.high_nbrs[j])):
            print("j is: ", j)
            print("i is: ", i)
            print("dfx.high_nbrs[j][i] node is, ", dfx.high_nbrs[j][i] )
            print("The status of it", dfx.Flag[dfx.Node == dfx.high_nbrs[j][i]].values)
            k = dfx.Flag[dfx.Node == dfx.high_nbrs[j][i]].values
            print("k is, check here", k )
            if (k == 'Diffused'):
                print("YESSSSSSS")       
                y = 1
        dfx['high_nbr_diff'][j] = y
    return dfx

# %%
k = 'Diffused'
if (k == 'Diffused'):
    print("Y")
# Out:
# Y

# %%
cols = ['Behavior', 'Node','Day', 'Flag','Nbrs', 'Num_Nbrs','Nbrs_Dffsed', 'Num_Nbrs_Dffsd','high_nbrs','high_nbr_diff',
        'Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm']
df2B_Diff_Algo2 = pd.DataFrame(columns=cols, index=range(len(nodes)))   # 100 need not be put in a afile. It will be modified once we have an external data source
for a in range(len(nodes)):
    df2B_Diff_Algo2.loc[a].Behavior = 'B'
    df2B_Diff_Algo2.loc[a].Node = nodes[a]
    df2B_Diff_Algo2.loc[a].Day = 100
    df2B_Diff_Algo2.loc[a].Flag = 'Not Diffused'
    #print(nodes[a])
    df2B_Diff_Algo2.loc[a].Nbrs = ''
    df2B_Diff_Algo2.loc[a].Num_Nbrs = 0
    df2B_Diff_Algo2.loc[a].Nbrs_Dffsed = ''
    df2B_Diff_Algo2.loc[a].Num_Nbrs_Dffsd = 0
    df2B_Diff_Algo2.loc[a].high_nbrs = [] 
    df2B_Diff_Algo2.loc[a].high_nbr_diff = 0
    df2B_Diff_Algo2.loc[a].Deg_Ctrlty = 0.0
    df2B_Diff_Algo2.loc[a].Probability = 0.0
    df2B_Diff_Algo2.loc[a].ratio = 0.0
    df2B_Diff_Algo2.loc[a].tcudorp = 0.0
    df2B_Diff_Algo2.loc[a].knar = 0
    df2B_Diff_Algo2.loc[a].knar_norm = 0

#df2C_Diff_Algo2
for i in range(len(df2B_Diff_Algo2)):
    df2B_Diff_Algo2.Nbrs[i] = G.neighbors(df2B_Diff_Algo2.loc[i].Node)
    df2B_Diff_Algo2.Deg_Ctrlty[i] = nx.degree_centrality(G)[df2B_Diff_Algo2.loc[i].Node]
for i in range(len(df2B_Diff_Algo2)):
    df2B_Diff_Algo2.Num_Nbrs[i] = len(df2B_Diff_Algo2.Nbrs[i])
    df2B_Diff_Algo2.Num_Nbrs_Dffsd[i] = len(df2B_Diff_Algo2.Nbrs_Dffsed[i])
    df2B_Diff_Algo2.Probability[i] = np.random.random()
    if df2B_Diff_Algo2.Probability[i] < 0.1:
        df2B_Diff_Algo2.Flag[i] = 'Resitant'
    if df2B_Diff_Algo2.Probability[i] > 0.9:
        df2B_Diff_Algo2.Flag[i] = 'Diffused'
        df2B_Diff_Algo2.Day[i] = 1

# %%
cols = ['Behavior', 'Node','Day', 'Flag','Nbrs', 'Num_Nbrs','Nbrs_Dffsed', 'Num_Nbrs_Dffsd', 'high_nbrs','high_nbr_diff', 
        'Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm']
df2C_Diff_Algo2 = pd.DataFrame(columns=cols, index=range(len(nodes)))   # 100 need not be put in a afile. It will be modified once we have an external data source
for a in range(len(nodes)):
    df2C_Diff_Algo2.loc[a].Behavior = 'C'
    df2C_Diff_Algo2.loc[a].Node = nodes[a]
    df2C_Diff_Algo2.loc[a].Day = 100
    df2C_Diff_Algo2.loc[a].Flag = 'Not Diffused'
    #print(nodes[a])
    df2C_Diff_Algo2.loc[a].Nbrs = ''
    df2C_Diff_Algo2.loc[a].Num_Nbrs = 0
    df2C_Diff_Algo2.loc[a].Nbrs_Dffsed = ''
    df2C_Diff_Algo2.loc[a].Num_Nbrs_Dffsd = 0
    df2C_Diff_Algo2.loc[a].high_nbrs = [] 
    df2C_Diff_Algo2.loc[a].high_nbr_diff = 0
    df2C_Diff_Algo2.loc[a].Deg_Ctrlty = 0.0
    df2C_Diff_Algo2.loc[a].Probability = 0.0
    df2C_Diff_Algo2.loc[a].ratio = 0.0
    df2C_Diff_Algo2.loc[a].tcudorp = 0.0
    df2C_Diff_Algo2.loc[a].knar = 0
    df2C_Diff_Algo2.loc[a].knar_norm = 0

#df2C_Diff_Algo2
for i in range(len(df2C_Diff_Algo2)):
    df2C_Diff_Algo2.Nbrs[i] = G.neighbors(df2C_Diff_Algo2.loc[i].Node)
    df2C_Diff_Algo2.Deg_Ctrlty[i] = nx.degree_centrality(G)[df2C_Diff_Algo2.loc[i].Node]
for i in range(len(df2C_Diff_Algo2)):
    df2C_Diff_Algo2.Num_Nbrs[i] = len(df2C_Diff_Algo2.Nbrs[i])
    df2C_Diff_Algo2.Num_Nbrs_Dffsd[i] = len(df2C_Diff_Algo2.Nbrs_Dffsed[i])
    df2C_Diff_Algo2.Probability[i] = np.random.random()
    if df2C_Diff_Algo2.Probability[i] < 0.1:
        df2C_Diff_Algo2.Flag[i] = 'Resitant'
    if df2C_Diff_Algo2.Probability[i] > 0.9:
        df2C_Diff_Algo2.Flag[i] = 'Diffused'
        df2C_Diff_Algo2.Day[i] = 1

# %%
df2B_Diff_Algo2 = high_nbrs(df2B_Diff_Algo2)
df2B_Diff_Algo2.sample(5)
# Out:
#    Behavior Node  Day          Flag              Nbrs Num_Nbrs Nbrs_Dffsed  \
# 12        B   13  100  Not Diffused      [44, 78, 83]        3
# 41        B   42  100  Not Diffused  [11, 25, 71, 93]        4
# 18        B   19  100  Not Diffused          [30, 60]        2
# 97        B   98  100      Resitant              [21]        1
# 3         B    4    1      Diffused      [12, 99, 86]        3
#
#    Num_Nbrs_Dffsd         high_nbrs high_nbr_diff Deg_Ctrlty Probability  \
# 12              0          [78, 83]             0   0.030303    0.666648
# 41              0  [11, 25, 71, 93]             0   0.040404    0.652847
# 18              0              [30]             0   0.020202     0.52728
# 97              0              [21]             0   0.010101   0.0244167
# 3               0              [12]             0   0.030303    0.906771
#
#    ratio tcudorp knar knar_norm
# 12     0       0    0         0
# 41     0       0    0         0
# 18     0       0    0         0
# 97     0       0    0         0
# 3      0       0    0         0

# %%
df2C_Diff_Algo2 = high_nbrs(df2C_Diff_Algo2)
df2C_Diff_Algo2.sample(5)
# Out:
#    Behavior Node  Day          Flag          Nbrs Num_Nbrs Nbrs_Dffsed  \
# 10        C   11  100  Not Diffused          [42]        1
# 3         C    4  100  Not Diffused  [12, 99, 86]        3
# 61        C   62  100  Not Diffused      [56, 86]        2
# 79        C   80  100  Not Diffused           [9]        1
# 18        C   19  100  Not Diffused      [30, 60]        2
#
#    Num_Nbrs_Dffsd high_nbrs high_nbr_diff Deg_Ctrlty Probability ratio  \
# 10              0      [42]             0   0.010101    0.143589     0
# 3               0      [12]             0   0.030303    0.265918     0
# 61              0      [86]             0   0.020202    0.898666     0
# 79              0       [9]             0   0.010101    0.175318     0
# 18              0      [30]             0   0.020202    0.665183     0
#
#    tcudorp knar knar_norm
# 10       0    0         0
# 3        0    0         0
# 61       0    0         0
# 79       0    0         0
# 18       0    0         0

# %%
df2B_Diff_Algo2['Nbrs'][5]
# Out:
# [92]

# %%
import time
start = time.time()
NumDays = 10
for j in (range(1, NumDays)):
    print("j is days and j is :" + str(j))
    df2B_Diff_Algo2 = realtion(df2B_Diff_Algo2)
    print("The check is from here")
    df2B_Diff_Algo2 = high_diffsd(df2B_Diff_Algo2)
    print("Till here")
    todivide = len(df2B_Diff_Algo2) - df2B_Diff_Algo2.knar.isnull().sum()
    df2B_Diff_Algo2['knar'] = df2B_Diff_Algo2.tcudorp[df2B_Diff_Algo2['Flag']=='Not Diffused'].rank(ascending=True)
    for i in range(len(df2B_Diff_Algo2)):
        #print("I am inside loop 1 & i is: "+ str(i))
        df2B_Diff_Algo2.tcudorp[i] = df2B_Diff_Algo2.ratio[i]+df2B_Diff_Algo2.Deg_Ctrlty[i]+df2B_Diff_Algo2.Probability[i]+df2B_Diff_Algo2.high_nbr_diff[i]/4
        if todivide == 0:
            df2B_Diff_Algo2.knar_norm[i] = 1
        else:
            df2B_Diff_Algo2.knar_norm[i] = df2B_Diff_Algo2.knar[i]/todivide
        for i in range(len(df2B_Diff_Algo2)):
        #print("I am inside loop 2 & new i is :"+ str(i))
            if(df2B_Diff_Algo2.knar_norm[i]<0.15):
                print("do i ever come here? " + str(i))
                df2B_Diff_Algo2.Flag[i] = 'Diffused'
                df2B_Diff_Algo2.Day[i] = j
end = time.time()
print(end-start)
# Out:
# j is days and j is :1
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# The check is from here
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  12
# i is:  1
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  24
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   del sys.path[0]
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  88
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  84
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  30
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  35
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  0
# The status of it []
# k is, check here []
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  1
# dfx.high_nbrs[j][i] node is,  82
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  94
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  55
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  11
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  1
# dfx.high_nbrs[j][i] node is,  25
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  2
# dfx.high_nbrs[j][i] node is,  71
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  3
# dfx.high_nbrs[j][i] node is,  93
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  70
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  1
# dfx.high_nbrs[j][i] node is,  95
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  2
# dfx.high_nbrs[j][i] node is,  89
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  50
# i is:  1
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  36
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  61
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  59
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  86
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  73
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  1
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  1
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  43
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  16
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  79
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  32
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# Till here
# do i ever come here? 1
# do i ever come here? 2
# do i ever come here? 3
# do i ever come here? 4
# do i ever come here? 5
# do i ever come here? 6
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 2
# do i ever come here? 3
# do i ever come here? 4
# do i ever come here? 5
# do i ever come here? 6
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 3
# do i ever come here? 4
# do i ever come here? 5
# do i ever come here? 6
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 4
# do i ever come here? 5
# do i ever come here? 6
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 5
# do i ever come here? 6
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 6
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 7
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 8
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 9
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 10
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 11
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 12
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 13
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 14
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 15
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# do i ever come here? 89
# do i ever come here? 90
# do i ever come here? 91
# do i ever come here? 92
# do i ever come here? 93
# do i ever come here? 94
# do i ever come here? 95
# do i ever come here? 96
# do i ever come here? 97
# do i ever come here? 98
# do i ever come here? 16
# do i ever come here? 17
# do i ever come here? 18
# do i ever come here? 19
# do i ever come here? 20
# do i ever come here? 21
# do i ever come here? 22
# do i ever come here? 23
# do i ever come here? 24
# do i ever come here? 25
# do i ever come here? 26
# do i ever come here? 27
# do i ever come here? 28
# do i ever come here? 29
# do i ever come here? 30
# do i ever come here? 31
# do i ever come here? 32
# do i ever come here? 33
# do i ever come here? 34
# do i ever come here? 35
# do i ever come here? 36
# do i ever come here? 37
# do i ever come here? 38
# do i ever come here? 39
# do i ever come here? 40
# do i ever come here? 41
# do i ever come here? 42
# do i ever come here? 43
# do i ever come here? 44
# do i ever come here? 45
# do i ever come here? 46
# do i ever come here? 47
# do i ever come here? 48
# do i ever come here? 49
# do i ever come here? 50
# do i ever come here? 51
# do i ever come here? 52
# do i ever come here? 53
# do i ever come here? 54
# do i ever come here? 55
# do i ever come here? 56
# do i ever come here? 57
# do i ever come here? 58
# do i ever come here? 59
# do i ever come here? 60
# do i ever come here? 61
# do i ever come here? 62
# do i ever come here? 63
# do i ever come here? 64
# do i ever come here? 65
# do i ever come here? 66
# do i ever come here? 67
# do i ever come here? 68
# do i ever come here? 69
# do i ever come here? 70
# do i ever come here? 71
# do i ever come here? 72
# do i ever come here? 73
# do i ever come here? 74
# do i ever come here? 75
# do i ever come here? 76
# do i ever come here? 77
# do i ever come here? 78
# do i ever come here? 79
# do i ever come here? 80
# do i ever come here? 81
# do i ever come here? 82
# do i ever come here? 83
# do i ever come here? 84
# do i ever come here? 85
# do i ever come here? 86
# do i ever come here? 87
# do i ever come here? 88
# ...
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  16
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  79
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  32
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# Till here
# j is days and j is :9
# The check is from here
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  12
# i is:  1
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  24
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  88
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  84
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  30
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  35
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  0
# The status of it []
# k is, check here []
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  29
# i is:  1
# dfx.high_nbrs[j][i] node is,  82
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  94
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  55
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  11
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  1
# dfx.high_nbrs[j][i] node is,  25
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  2
# dfx.high_nbrs[j][i] node is,  71
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  3
# dfx.high_nbrs[j][i] node is,  93
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  70
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  45
# i is:  1
# dfx.high_nbrs[j][i] node is,  95
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  45
# i is:  2
# dfx.high_nbrs[j][i] node is,  89
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  50
# i is:  1
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  36
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  61
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  59
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  86
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  73
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  66
# i is:  1
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  1
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  43
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  16
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  79
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  32
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# Till here
# 424.7979278564453

# %%
k = df2B_Diff_Algo2[df2B_Diff_Algo2['Node']==32]['Flag']
k
# Out:
# 31    Diffused
# Name: Flag, dtype: object

# %%
import time
start = time.time()
NumDays = 10
for j in (range(1, NumDays)):
    print("j is days and j is :" + str(j))
    df2C_Diff_Algo2 = realtion(df2C_Diff_Algo2)
    df2C_Diff_Algo2 = high_diffsd(df2C_Diff_Algo2)
    todivide = len(df2C_Diff_Algo2) - df2C_Diff_Algo2.knar.isnull().sum()
    df2C_Diff_Algo2['knar'] = df2C_Diff_Algo2.tcudorp[df2C_Diff_Algo2['Flag']=='Not Diffused'].rank(ascending=True)
    for i in range(len(df2C_Diff_Algo2)):
        print("I am inside loop 1 & i is: "+ str(i))
        df2C_Diff_Algo2.tcudorp[i] = df2C_Diff_Algo2.ratio[i]+df2C_Diff_Algo2.Deg_Ctrlty[i]+df2C_Diff_Algo2.Probability[i]+df2C_Diff_Algo2.high_nbr_diff[i]/4
        if todivide == 0:
            df2C_Diff_Algo2.knar_norm[i] = 1
        else:
            df2C_Diff_Algo2.knar_norm[i] = df2C_Diff_Algo2.knar[i]/todivide
    for i in range(len(df2C_Diff_Algo2)):
        print("I am inside loop 2 & new i is :"+ str(i))
        if(df2C_Diff_Algo2.knar_norm[i]<0.15):
            print("do i ever come here? " + str(i))
            df2C_Diff_Algo2.Flag[i] = 'Diffused'
            df2C_Diff_Algo2.Day[i] = j
end = time.time()
print(end-start)
# Out:
# j is days and j is :1
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  12
# i is:  1
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  24
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  88
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  84
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  30
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  35
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  0
# The status of it []
# k is, check here []
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  1
# dfx.high_nbrs[j][i] node is,  82
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  94
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  55
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   del sys.path[0]
#  15
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  11
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  1
# dfx.high_nbrs[j][i] node is,  25
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  2
# dfx.high_nbrs[j][i] node is,  71
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  3
# dfx.high_nbrs[j][i] node is,  93
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  70
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  45
# i is:  1
# dfx.high_nbrs[j][i] node is,  95
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  2
# dfx.high_nbrs[j][i] node is,  89
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  50
# i is:  1
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  36
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  61
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  59
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  86
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  73
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  1
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  1
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  43
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  16
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  79
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# ['Not Diffused']
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  32
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# I am inside loop 1 & i is: 0
# I am inside loop 1 & i is: 1
# I am inside loop 1 & i is: 2
# I am inside loop 1 & i is: 3
# I am inside loop 1 & i is: 4
# I am inside loop 1 & i is: 5
# I am inside loop 1 & i is: 6
# I am inside loop 1 & i is: 7
# I am inside loop 1 & i is: 8
# I am inside loop 1 & i is: 9
# I am inside loop 1 & i is: 10
# I am inside loop 1 & i is: 11
# I am inside loop 1 & i is: 12
# I am inside loop 1 & i is: 13
# I am inside loop 1 & i is: 14
# I am inside loop 1 & i is: 15
# I am inside loop 1 & i is: 16
# I am inside loop 1 & i is: 17
# I am inside loop 1 & i is: 18
# I am inside loop 1 & i is: 19
# I am inside loop 1 & i is: 20
# I am inside loop 1 & i is: 21
# I am inside loop 1 & i is: 22
# I am inside loop 1 & i is: 23
# I am inside loop 1 & i is: 24
# I am inside loop 1 & i is: 25
# I am inside loop 1 & i is: 26
# I am inside loop 1 & i is: 27
# I am inside loop 1 & i is: 28
# I am inside loop 1 & i is: 29
# I am inside loop 1 & i is: 30
# I am inside loop 1 & i is: 31
# I am inside loop 1 & i is: 32
# I am inside loop 1 & i is: 33
# I am inside loop 1 & i is: 34
# I am inside loop 1 & i is: 35
# I am inside loop 1 & i is: 36
# I am inside loop 1 & i is: 37
# I am inside loop 1 & i is: 38
# I am inside loop 1 & i is: 39
# I am inside loop 1 & i is: 40
# I am inside loop 1 & i is: 41
# I am inside loop 1 & i is: 42
# I am inside loop 1 & i is: 43
# I am inside loop 1 & i is: 44
# I am inside loop 1 & i is: 45
# I am inside loop 1 & i is: 46
# I am inside loop 1 & i is: 47
# I am inside loop 1 & i is: 48
# I am inside loop 1 & i is: 49
# I am inside loop 1 & i is: 50
# I am inside loop 1 & i is: 51
# I am inside loop 1 & i is: 52
# I am inside loop 1 & i is: 53
# I am inside loop 1 & i is: 54
# I am inside loop 1 & i is: 55
# I am inside loop 1 & i is: 56
# I am inside loop 1 & i is: 57
# I am inside loop 1 & i is: 58
# I am inside loop 1 & i is: 59
# I am inside loop 1 & i is: 60
# I am inside loop 1 & i is: 61
# I am inside loop 1 & i is: 62
# I am inside loop 1 & i is: 63
# I am inside loop 1 & i is: 64
# I am inside loop 1 & i is: 65
# I am inside loop 1 & i is: 66
# I am inside loop 1 & i is: 67
# I am inside loop 1 & i is: 68
# I am inside loop 1 & i is: 69
# I am inside loop 1 & i is: 70
# I am inside loop 1 & i is: 71
# I am inside loop 1 & i is: 72
# I am inside loop 1 & i is: 73
# I am inside loop 1 & i is: 74
# I am inside loop 1 & i is: 75
# I am inside loop 1 & i is: 76
# I am inside loop 1 & i is: 77
# I am inside loop 1 & i is: 78
# I am inside loop 1 & i is: 79
# I am inside loop 1 & i is: 80
# I am inside loop 1 & i is: 81
# I am inside loop 1 & i is: 82
# I am inside loop 1 & i is: 83
# I am inside loop 1 & i is: 84
# I am inside loop 1 & i is: 85
# I am inside loop 1 & i is: 86
# I am inside loop 1 & i is: 87
# I am inside loop 1 & i is: 88
# I am inside loop 1 & i is: 89
# I am inside loop 1 & i is: 90
# I am inside loop 1 & i is: 91
# I am inside loop 1 & i is: 92
# I am inside loop 1 & i is: 93
# I am inside loop 1 & i is: 94
# I am inside loop 1 & i is: 95
# I am inside loop 1 & i is: 96
# I am inside loop 1 & i is: 97
# I am inside loop 1 & i is: 98
# I am inside loop 2 & new i is :0
# I am inside loop 2 & new i is :1
# I am inside loop 2 & new i is :2
# I am inside loop 2 & new i is :3
# I am inside loop 2 & new i is :4
# I am inside loop 2 & new i is :5
# I am inside loop 2 & new i is :6
# I am inside loop 2 & new i is :7
# I am inside loop 2 & new i is :8
# I am inside loop 2 & new i is :9
# I am inside loop 2 & new i is :10
# I am inside loop 2 & new i is :11
# I am inside loop 2 & new i is :12
# I am inside loop 2 & new i is :13
# I am inside loop 2 & new i is :14
# I am inside loop 2 & new i is :15
# I am inside loop 2 & new i is :16
# I am inside loop 2 & new i is :17
# I am inside loop 2 & new i is :18
# I am inside loop 2 & new i is :19
# I am inside loop 2 & new i is :20
# I am inside loop 2 & new i is :21
# I am inside loop 2 & new i is :22
# I am inside loop 2 & new i is :23
# I am inside loop 2 & new i is :24
# I am inside loop 2 & new i is :25
# I am inside loop 2 & new i is :26
# I am inside loop 2 & new i is :27
# I am inside loop 2 & new i is :28
# I am inside loop 2 & new i is :29
# I am inside loop 2 & new i is :30
# I am inside loop 2 & new i is :31
# I am inside loop 2 & new i is :32
# I am inside loop 2 & new i is :33
# I am inside loop 2 & new i is :34
# I am inside loop 2 & new i is :35
# I am inside loop 2 & new i is :36
# I am inside loop 2 & new i is :37
# I am inside loop 2 & new i is :38
# I am inside loop 2 & new i is :39
# I am inside loop 2 & new i is :40
# I am inside loop 2 & new i is :41
# I am inside loop 2 & new i is :42
# I am inside loop 2 & new i is :43
# I am inside loop 2 & new i is :44
# I am inside loop 2 & new i is :45
# I am inside loop 2 & new i is :46
# I am inside loop 2 & new i is :47
# I am inside loop 2 & new i is :48
# I am inside loop 2 & new i is :49
# I am inside loop 2 & new i is :50
# I am inside loop 2 & new i is :51
# I am inside loop 2 & new i is :52
# I am inside loop 2 & new i is :53
# I am inside loop 2 & new i is :54
# I am inside loop 2 & new i is :55
# I am inside loop 2 & new i is :56
# I am inside loop 2 & new i is :57
# I am inside loop 2 & new i is :58
# I am inside loop 2 & new i is :59
# I am inside loop 2 & new i is :60
# I am inside loop 2 & new i is :61
# I am inside loop 2 & new i is :62
# I am inside loop 2 & new i is :63
# I am inside loop 2 & new i is :64
# I am inside loop 2 & new i is :65
# I am inside loop 2 & new i is :66
# I am inside loop 2 & new i is :67
# I am inside loop 2 & new i is :68
# I am inside loop 2 & new i is :69
# I am inside loop 2 & new i is :70
# I am inside loop 2 & new i is :71
# I am inside loop 2 & new i is :72
# I am inside loop 2 & new i is :73
# I am inside loop 2 & new i is :74
# I am inside loop 2 & new i is :75
# I am inside loop 2 & new i is :76
# I am inside loop 2 & new i is :77
# I am inside loop 2 & new i is :78
# I am inside loop 2 & new i is :79
# I am inside loop 2 & new i is :80
# I am inside loop 2 & new i is :81
# I am inside loop 2 & new i is :82
# I am inside loop 2 & new i is :83
# I am inside loop 2 & new i is :84
# I am inside loop 2 & new i is :85
# I am inside loop 2 & new i is :86
# I am inside loop 2 & new i is :87
# I am inside loop 2 & new i is :88
# I am inside loop 2 & new i is :89
# I am inside loop 2 & new i is :90
# I am inside loop 2 & new i is :91
# I am inside loop 2 & new i is :92
# I am inside loop 2 & new i is :93
# I am inside loop 2 & new i is :94
# I am inside loop 2 & new i is :95
# I am inside loop 2 & new i is :96
# I am inside loop 2 & new i is :97
# I am inside loop 2 & new i is :98
# j is days and j is :2
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  12
# i is:  1
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  24
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  88
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  84
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  30
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  35
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  0
# The status of it []
# k is, check here []
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  1
# dfx.high_nbrs[j][i] node is,  82
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  94
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  55
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  11
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  1
# dfx.high_nbrs[j][i] node is,  25
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  2
# dfx.high_nbrs[j][i] node is,  71
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  3
# dfx.high_nbrs[j][i] node is,  93
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  70
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  45
# i is:  1
# dfx.high_nbrs[j][i] node is,  95
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  2
# dfx.high_nbrs[j][i] node is,  89
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  50
# i is:  1
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  36
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  61
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  59
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  86
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  73
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  1
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  1
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  37
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  43
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  16
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  79
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  32
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# I am inside loop 1 & i is: 0
# I am inside loop 1 & i is: 1
# I am inside loop 1 & i is: 2
# I am inside loop 1 & i is: 3
# I am inside loop 1 & i is: 4
# I am inside loop 1 & i is: 5
# I am inside loop 1 & i is: 6
# I am inside loop 1 & i is: 7
# I am inside loop 1 & i is: 8
# I am inside loop 1 & i is: 9
# I am inside loop 1 & i is: 10
# I am inside loop 1 & i is: 11
# I am inside loop 1 & i is: 12
# I am inside loop 1 & i is: 13
# I am inside loop 1 & i is: 14
# I am inside loop 1 & i is: 15
# I am inside loop 1 & i is: 16
# I am inside loop 1 & i is: 17
# I am inside loop 1 & i is: 18
# I am inside loop 1 & i is: 19
# I am inside loop 1 & i is: 20
# I am inside loop 1 & i is: 21
# I am inside loop 1 & i is: 22
# I am inside loop 1 & i is: 23
# I am inside loop 1 & i is: 24
# I am inside loop 1 & i is: 25
# I am inside loop 1 & i is: 26
# I am inside loop 1 & i is: 27
# I am inside loop 1 & i is: 28
# I am inside loop 1 & i is: 29
# I am inside loop 1 & i is: 30
# I am inside loop 1 & i is: 31
# I am inside loop 1 & i is: 32
# I am inside loop 1 & i is: 33
# I am inside loop 1 & i is: 34
# I am inside loop 1 & i is: 35
# I am inside loop 1 & i is: 36
# I am inside loop 1 & i is: 37
# I am inside loop 1 & i is: 38
# I am inside loop 1 & i is: 39
# I am inside loop 1 & i is: 40
# I am inside loop 1 & i is: 41
# I am inside loop 1 & i is: 42
# I am inside loop 1 & i is: 43
# I am inside loop 1 & i is: 44
# I am inside loop 1 & i is: 45
# I am inside loop 1 & i is: 46
# I am inside loop 1 & i is: 47
# I am inside loop 1 & i is: 48
# I am inside loop 1 & i is: 49
# I am inside loop 1 & i is: 50
# I am inside loop 1 & i is: 51
# I am inside loop 1 & i is: 52
# I am inside loop 1 & i is: 53
# I am inside loop 1 & i is: 54
# I am inside loop 1 & i is: 55
# I am inside loop 1 & i is: 56
# I am inside loop 1 & i is: 57
# I am inside loop 1 & i is: 58
# I am inside loop 1 & i is: 59
# I am inside loop 1 & i is: 60
# I am inside loop 1 & i is: 61
# I am inside loop 1 & i is: 62
# I am inside loop 1 & i is: 63
# I am inside loop 1 & i is: 64
# I am inside loop 1 & i is: 65
# I am inside loop 1 & i is: 66
# I am inside loop 1 & i is: 67
# I am inside loop 1 & i is: 68
# I am inside loop 1 & i is: 69
# I am inside loop 1 & i is: 70
# I am inside loop 1 & i is: 71
# I am inside loop 1 & i is: 72
# I am inside loop 1 & i is: 73
# I am inside loop 1 & i is: 74
# I am inside loop 1 & i is: 75
# I am inside loop 1 & i is: 76
# I am inside loop 1 & i is: 77
# I am inside loop 1 & i is: 78
# I am inside loop 1 & i is: 79
# I am inside loop 1 & i is: 80
# I am inside loop 1 & i is: 81
# I am inside loop 1 & i is: 82
# I am inside loop 1 & i is: 83
# I am inside loop 1 & i is: 84
# I am inside loop 1 & i is: 85
# I am inside loop 1 & i is: 86
# I am inside loop 1 & i is: 87
# I am inside loop 1 & i is: 88
# I am inside loop 1 & i is: 89
# I am inside loop 1 & i is: 90
# I am inside loop 1 & i is: 91
# I am inside loop 1 & i is: 92
# I am inside loop 1 & i is: 93
# I am inside loop 1 & i is: 94
# I am inside loop 1 & i is: 95
# I am inside loop 1 & i is: 96
# I am inside loop 1 & i is: 97
# I am inside loop 1 & i is: 98
# I am inside loop 2 & new i is :0
# I am inside loop 2 & new i is :1
# I am inside loop 2 & new i is :2
# I am inside loop 2 & new i is :3
# do i ever come here? 3
# I am inside loop 2 & new i is :4
# do i ever come here? 4
# I am inside loop 2 & new i is :5
# I am inside loop 2 & new i is :6
# I am inside loop 2 & new i is :7
# I am inside loop 2 & new i is :8
# I am inside loop 2 & new i is :9
# do i ever come here? 9
# I am inside loop 2 & new i is :10
# do i ever come here? 10
# I am inside loop 2 & new i is :11
# I am inside loop 2 & new i is :12
# I am inside loop 2 & new i is :13
# I am inside loop 2 & new i is :14
# I am inside loop 2 & new i is :15
# I am inside loop 2 & new i is :16
# I am inside loop 2 & new i is :17
# I am inside loop 2 & new i is :18
# I am inside loop 2 & new i is :19
# I am inside loop 2 & new i is :20
# I am inside loop 2 & new i is :21
# I am inside loop 2 & new i is :22
# I am inside loop 2 & new i is :23
# I am inside loop 2 & new i is :24
# I am inside loop 2 & new i is :25
# I am inside loop 2 & new i is :26
# I am inside loop 2 & new i is :27
# I am inside loop 2 & new i is :28
# I am inside loop 2 & new i is :29
# I am inside loop 2 & new i is :30
# I am inside loop 2 & new i is :31
# I am inside loop 2 & new i is :32
# do i ever come here? 32
# I am inside loop 2 & new i is :33
# I am inside loop 2 & new i is :34
# I am inside loop 2 & new i is :35
# I am inside loop 2 & new i is :36
# I am inside loop 2 & new i is :37
# I am inside loop 2 & new i is :38
# I am inside loop 2 & new i is :39
# I am inside loop 2 & new i is :40
# I am inside loop 2 & new i is :41
# I am inside loop 2 & new i is :42
# I am inside loop 2 & new i is :43
# I am inside loop 2 & new i is :44
# I am inside loop 2 & new i is :45
# I am inside loop 2 & new i is :46
# I am inside loop 2 & new i is :47
# I am inside loop 2 & new i is :48
# I am inside loop 2 & new i is :49
# I am inside loop 2 & new i is :50
# I am inside loop 2 & new i is :51
# I am inside loop 2 & new i is :52
# I am inside loop 2 & new i is :53
# I am inside loop 2 & new i is :54
# I am inside loop 2 & new i is :55
# I am inside loop 2 & new i is :56
# I am inside loop 2 & new i is :57
# I am inside loop 2 & new i is :58
# I am inside loop 2 & new i is :59
# I am inside loop 2 & new i is :60
# I am inside loop 2 & new i is :61
# I am inside loop 2 & new i is :62
# do i ever come here? 62
# I am inside loop 2 & new i is :63
# I am inside loop 2 & new i is :64
# do i ever come here? 64
# I am inside loop 2 & new i is :65
# I am inside loop 2 & new i is :66
# I am inside loop 2 & new i is :67
# I am inside loop 2 & new i is :68
# I am inside loop 2 & new i is :69
# I am inside loop 2 & new i is :70
# do i ever come here? 70
# I am inside loop 2 & new i is :71
# do i ever come here? 71
# I am inside loop 2 & new i is :72
# I am inside loop 2 & new i is :73
# I am inside loop 2 & new i is :74
# I am inside loop 2 & new i is :75
# I am inside loop 2 & new i is :76
# I am inside loop 2 & new i is :77
# I am inside loop 2 & new i is :78
# I am inside loop 2 & new i is :79
# do i ever come here? 79
# I am inside loop 2 & new i is :80
# I am inside loop 2 & new i is :81
# do i ever come here? 81
# I am inside loop 2 & new i is :82
# I am inside loop 2 & new i is :83
# I am inside loop 2 & new i is :84
# I am inside loop 2 & new i is :85
# I am inside loop 2 & new i is :86
# I am inside loop 2 & new i is :87
# I am inside loop 2 & new i is :88
# I am inside loop 2 & new i is :89
# I am inside loop 2 & new i is :90
# I am inside loop 2 & new i is :91
# I am inside loop 2 & new i is :92
# I am inside loop 2 & new i is :93
# I am inside loop 2 & new i is :94
# I am inside loop 2 & new i is :95
# I am inside loop 2 & new i is :96
# I am inside loop 2 & new i is :97
# I am inside loop 2 & new i is :98
# j is days and j is :3
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  12
# i is:  1
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  24
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  88
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  84
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  30
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  35
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  0
# The status of it []
# k is, check here []
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  29
# i is:  1
# dfx.high_nbrs[j][i] node is,  82
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  94
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  55
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  11
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  1
# dfx.high_nbrs[j][i] node is,  25
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  2
# dfx.high_nbrs[j][i] node is,  71
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  3
# dfx.high_nbrs[j][i] node is,  93
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  70
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  45
# i is:  1
# dfx.high_nbrs[j][i] node is,  95
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  45
# i is:  2
# dfx.high_nbrs[j][i] node is,  89
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# ...
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  29
# i is:  1
# dfx.high_nbrs[j][i] node is,  82
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  94
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  55
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  11
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  1
# dfx.high_nbrs[j][i] node is,  25
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  41
# i is:  2
# dfx.high_nbrs[j][i] node is,  71
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  41
# i is:  3
# dfx.high_nbrs[j][i] node is,  93
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  70
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  45
# i is:  1
# dfx.high_nbrs[j][i] node is,  95
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  45
# i is:  2
# dfx.high_nbrs[j][i] node is,  89
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  50
# i is:  1
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  36
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  61
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  19
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  59
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  86
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  73
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  58
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  66
# i is:  1
# dfx.high_nbrs[j][i] node is,  75
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  1
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  43
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  39
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  83
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  16
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  79
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  51
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  92
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  78
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  3
# The status of it ['Resitant']
# k is, check here ['Resitant']
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  42
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  32
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  12
# The status of it ['Not Diffused']
# k is, check here ['Not Diffused']
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  21
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  4
# The status of it ['Diffused']
# k is, check here ['Diffused']
# YESSSSSSS
# I am inside loop 1 & i is: 0
# I am inside loop 1 & i is: 1
# I am inside loop 1 & i is: 2
# I am inside loop 1 & i is: 3
# I am inside loop 1 & i is: 4
# I am inside loop 1 & i is: 5
# I am inside loop 1 & i is: 6
# I am inside loop 1 & i is: 7
# I am inside loop 1 & i is: 8
# I am inside loop 1 & i is: 9
# I am inside loop 1 & i is: 10
# I am inside loop 1 & i is: 11
# I am inside loop 1 & i is: 12
# I am inside loop 1 & i is: 13
# I am inside loop 1 & i is: 14
# I am inside loop 1 & i is: 15
# I am inside loop 1 & i is: 16
# I am inside loop 1 & i is: 17
# I am inside loop 1 & i is: 18
# I am inside loop 1 & i is: 19
# I am inside loop 1 & i is: 20
# I am inside loop 1 & i is: 21
# I am inside loop 1 & i is: 22
# I am inside loop 1 & i is: 23
# I am inside loop 1 & i is: 24
# I am inside loop 1 & i is: 25
# I am inside loop 1 & i is: 26
# I am inside loop 1 & i is: 27
# I am inside loop 1 & i is: 28
# I am inside loop 1 & i is: 29
# I am inside loop 1 & i is: 30
# I am inside loop 1 & i is: 31
# I am inside loop 1 & i is: 32
# I am inside loop 1 & i is: 33
# I am inside loop 1 & i is: 34
# I am inside loop 1 & i is: 35
# I am inside loop 1 & i is: 36
# I am inside loop 1 & i is: 37
# I am inside loop 1 & i is: 38
# I am inside loop 1 & i is: 39
# I am inside loop 1 & i is: 40
# I am inside loop 1 & i is: 41
# I am inside loop 1 & i is: 42
# I am inside loop 1 & i is: 43
# I am inside loop 1 & i is: 44
# I am inside loop 1 & i is: 45
# I am inside loop 1 & i is: 46
# I am inside loop 1 & i is: 47
# I am inside loop 1 & i is: 48
# I am inside loop 1 & i is: 49
# I am inside loop 1 & i is: 50
# I am inside loop 1 & i is: 51
# I am inside loop 1 & i is: 52
# I am inside loop 1 & i is: 53
# I am inside loop 1 & i is: 54
# I am inside loop 1 & i is: 55
# I am inside loop 1 & i is: 56
# I am inside loop 1 & i is: 57
# I am inside loop 1 & i is: 58
# I am inside loop 1 & i is: 59
# I am inside loop 1 & i is: 60
# I am inside loop 1 & i is: 61
# I am inside loop 1 & i is: 62
# I am inside loop 1 & i is: 63
# I am inside loop 1 & i is: 64
# I am inside loop 1 & i is: 65
# I am inside loop 1 & i is: 66
# I am inside loop 1 & i is: 67
# I am inside loop 1 & i is: 68
# I am inside loop 1 & i is: 69
# I am inside loop 1 & i is: 70
# I am inside loop 1 & i is: 71
# I am inside loop 1 & i is: 72
# I am inside loop 1 & i is: 73
# I am inside loop 1 & i is: 74
# I am inside loop 1 & i is: 75
# I am inside loop 1 & i is: 76
# I am inside loop 1 & i is: 77
# I am inside loop 1 & i is: 78
# I am inside loop 1 & i is: 79
# I am inside loop 1 & i is: 80
# I am inside loop 1 & i is: 81
# I am inside loop 1 & i is: 82
# I am inside loop 1 & i is: 83
# I am inside loop 1 & i is: 84
# I am inside loop 1 & i is: 85
# I am inside loop 1 & i is: 86
# I am inside loop 1 & i is: 87
# I am inside loop 1 & i is: 88
# I am inside loop 1 & i is: 89
# I am inside loop 1 & i is: 90
# I am inside loop 1 & i is: 91
# I am inside loop 1 & i is: 92
# I am inside loop 1 & i is: 93
# I am inside loop 1 & i is: 94
# I am inside loop 1 & i is: 95
# I am inside loop 1 & i is: 96
# I am inside loop 1 & i is: 97
# I am inside loop 1 & i is: 98
# I am inside loop 2 & new i is :0
# I am inside loop 2 & new i is :1
# I am inside loop 2 & new i is :2
# I am inside loop 2 & new i is :3
# I am inside loop 2 & new i is :4
# I am inside loop 2 & new i is :5
# I am inside loop 2 & new i is :6
# I am inside loop 2 & new i is :7
# I am inside loop 2 & new i is :8
# I am inside loop 2 & new i is :9
# I am inside loop 2 & new i is :10
# I am inside loop 2 & new i is :11
# I am inside loop 2 & new i is :12
# I am inside loop 2 & new i is :13
# I am inside loop 2 & new i is :14
# I am inside loop 2 & new i is :15
# I am inside loop 2 & new i is :16
# I am inside loop 2 & new i is :17
# I am inside loop 2 & new i is :18
# I am inside loop 2 & new i is :19
# I am inside loop 2 & new i is :20
# I am inside loop 2 & new i is :21
# I am inside loop 2 & new i is :22
# I am inside loop 2 & new i is :23
# I am inside loop 2 & new i is :24
# I am inside loop 2 & new i is :25
# I am inside loop 2 & new i is :26
# I am inside loop 2 & new i is :27
# I am inside loop 2 & new i is :28
# I am inside loop 2 & new i is :29
# I am inside loop 2 & new i is :30
# I am inside loop 2 & new i is :31
# I am inside loop 2 & new i is :32
# I am inside loop 2 & new i is :33
# I am inside loop 2 & new i is :34
# I am inside loop 2 & new i is :35
# I am inside loop 2 & new i is :36
# I am inside loop 2 & new i is :37
# I am inside loop 2 & new i is :38
# I am inside loop 2 & new i is :39
# I am inside loop 2 & new i is :40
# I am inside loop 2 & new i is :41
# I am inside loop 2 & new i is :42
# I am inside loop 2 & new i is :43
# I am inside loop 2 & new i is :44
# I am inside loop 2 & new i is :45
# I am inside loop 2 & new i is :46
# I am inside loop 2 & new i is :47
# do i ever come here? 47
# I am inside loop 2 & new i is :48
# I am inside loop 2 & new i is :49
# I am inside loop 2 & new i is :50
# I am inside loop 2 & new i is :51
# I am inside loop 2 & new i is :52
# I am inside loop 2 & new i is :53
# I am inside loop 2 & new i is :54
# do i ever come here? 54
# I am inside loop 2 & new i is :55
# I am inside loop 2 & new i is :56
# I am inside loop 2 & new i is :57
# I am inside loop 2 & new i is :58
# I am inside loop 2 & new i is :59
# I am inside loop 2 & new i is :60
# I am inside loop 2 & new i is :61
# I am inside loop 2 & new i is :62
# I am inside loop 2 & new i is :63
# I am inside loop 2 & new i is :64
# I am inside loop 2 & new i is :65
# I am inside loop 2 & new i is :66
# I am inside loop 2 & new i is :67
# I am inside loop 2 & new i is :68
# I am inside loop 2 & new i is :69
# I am inside loop 2 & new i is :70
# I am inside loop 2 & new i is :71
# I am inside loop 2 & new i is :72
# I am inside loop 2 & new i is :73
# I am inside loop 2 & new i is :74
# I am inside loop 2 & new i is :75
# I am inside loop 2 & new i is :76
# I am inside loop 2 & new i is :77
# I am inside loop 2 & new i is :78
# I am inside loop 2 & new i is :79
# I am inside loop 2 & new i is :80
# I am inside loop 2 & new i is :81
# I am inside loop 2 & new i is :82
# I am inside loop 2 & new i is :83
# I am inside loop 2 & new i is :84
# I am inside loop 2 & new i is :85
# do i ever come here? 85
# I am inside loop 2 & new i is :86
# I am inside loop 2 & new i is :87
# I am inside loop 2 & new i is :88
# I am inside loop 2 & new i is :89
# I am inside loop 2 & new i is :90
# I am inside loop 2 & new i is :91
# I am inside loop 2 & new i is :92
# I am inside loop 2 & new i is :93
# I am inside loop 2 & new i is :94
# I am inside loop 2 & new i is :95
# I am inside loop 2 & new i is :96
# I am inside loop 2 & new i is :97
# I am inside loop 2 & new i is :98
# do i ever come here? 98
# 174.90683960914612

# %%
df2B_Diff_Algo2.sample(5)
# Out:
#    Behavior Node Day      Flag          Nbrs Num_Nbrs Nbrs_Dffsed  \
# 26        B   27   1  Diffused          [77]        1          []
# 45        B   46   1  Diffused  [70, 95, 89]        3          []
# 34        B   35   1  Diffused          [22]        1          []
# 33        B   34   1  Diffused      [17, 78]        2          []
# 86        B   87   1  Diffused          [51]        1          []
#
#    Num_Nbrs_Dffsd     high_nbrs high_nbr_diff Deg_Ctrlty Probability ratio  \
# 26              0          [77]             1   0.010101    0.338192     0
# 45              0  [70, 95, 89]             1   0.030303    0.243217     0
# 34              0          [22]             1   0.010101     0.93599     0
# 33              0          [78]             1   0.020202      0.8711     0
# 86              0          [51]             1   0.010101     0.94291     0
#
#      tcudorp  knar knar_norm
# 26  0.598293   NaN         1
# 45   0.52352   NaN         1
# 34   1.19609   NaN         1
# 33    1.1413   NaN         1
# 86   1.20301   NaN         1

# %%
df2B_Diff_Algo2.groupby(["Flag"]).size()
# Out:
# Flag
# Diffused    98
# Resitant     1
# dtype: int64

# %%
df2C_Diff_Algo2.groupby(["Flag"]).size()
# Out:
# Flag
# Diffused        67
# Not Diffused    19
# Resitant        13
# dtype: int64

# %%
df2A.shape
# Out:
# (55, 12)

# %% [markdown]
# ### Trimming of the Tables

# %%
df2A.sample(10)
# Out:
#    Behavior Node                Time                 min             lag  \
# 40        A   75 2016-01-11 10:39:54 2016-01-01 16:26:01 9 days 18:13:53
# 26        A   45 2016-01-10 19:33:07 2016-01-01 16:26:01 9 days 03:07:06
# 21        A   36 2016-01-05 19:06:21 2016-01-01 16:26:01 4 days 02:40:20
# 1         A    3 2016-01-11 03:28:10 2016-01-01 16:26:01 9 days 11:02:09
# 6         A   10 2016-01-03 21:55:41 2016-01-01 16:26:01 2 days 05:29:40
# 8         A   14 2016-01-03 02:35:45 2016-01-01 16:26:01 1 days 10:09:44
# 50        A   94 2016-01-08 02:13:34 2016-01-01 16:26:01 6 days 09:47:33
# 33        A   58 2016-01-07 19:53:24 2016-01-01 16:26:01 6 days 03:27:23
# 49        A   93 2016-01-05 17:47:58 2016-01-01 16:26:01 4 days 01:21:57
# 4         A    6 2016-01-03 21:54:07 2016-01-01 16:26:01 2 days 05:28:06
#
#     lag2                   Neighbors  Deg_Cntrlty relation  ratio  \
# 40     9                    [41, 67]     0.020202             0.0
# 26     9                        [54]     0.010101             0.0
# 21     4                        [55]     0.010101             0.0
# 1      9  [5, 92, 10, 47, 21, 51, 8]     0.070707             0.0
# 6      2                         [3]     0.010101             0.0
# 8      1                        [24]     0.010101             0.0
# 50     6                        [31]     0.010101             0.0
# 33     6                    [57, 67]     0.020202             0.0
# 49     4                        [42]     0.010101             0.0
# 4      2                        [92]     0.010101             0.0
#
#     inflncr_scr high_nbrs
# 40            0      [67]
# 26            0      [54]
# 21            0      [55]
# 1             0      [51]
# 6             0       [3]
# 8             0      [24]
# 50            0      [31]
# 33            0      [67]
# 49            0      [42]
# 4             0      [92]

# %%
#j = 101
#for i in range(len(df2C_Diff_Algo2)):
#    if(df2C_Diff_Algo2.knar[i]<0.25):
#        df2C_Diff_Algo2.Flag[i] = 'Diffused'
#        df2C_Diff_Algo2.Day[i] = j
        
#df2C_Diff_Algo2

# %%
#for j in (range(1, 10)):
#    print("j is days and j is :" + str(j))
#    df2C_Diff_Algo2 = realtion(df2C_Diff_Algo2)
#    todivide = len(df2C_Diff_Algo2) - df2C_Diff_Algo2.knar.isnull().sum()
#    df2C_Diff_Algo2['knar'] = df2C_Diff_Algo2.tcudorp[df2C_Diff_Algo2['Flag']=='Not Diffused'].rank(ascending=True)
#    for i in range(len(df2C_Diff_Algo2)):
#        print("I am inside loop 1"+ str(i))
#        df2C_Diff_Algo2.tcudorp[i] = df2C_Diff_Algo2.ratio[i]*df2C_Diff_Algo2.Deg_Ctrlty[i]*df2C_Diff_Algo2.Probability[i]
#        df2C_Diff_Algo2.knar_norm[i] = df2C_Diff_Algo2.knar[i]/todivide
#    for i in range(len(df2C_Diff_Algo2)):
#        print("I am inside loop 2"+ str(i))
#        if(df2C_Diff_Algo2.knar_norm[i]<0.25):
#            print("do i ever come here? " + str(i))
#            df2C_Diff_Algo2.Flag[i] = 'Diffused'
#            df2C_Diff_Algo2.Day[i] = j

# %%
df2C_Diff_Algo2.sample(10)
# Out:
#    Behavior Node  Day          Flag          Nbrs Num_Nbrs   Nbrs_Dffsed  \
# 25        C   26    6      Diffused          [92]        1            []
# 95        C   96  100      Resitant          [32]        1          [32]
# 23        C   24    5      Diffused          [14]        1          [14]
# 1         C    2  100  Not Diffused          [51]        1          [51]
# 26        C   27  100  Not Diffused          [77]        1          [77]
# 85        C   86    9      Diffused       [4, 62]        2       [4, 62]
# 61        C   62    8      Diffused      [56, 86]        2          [56]
# 52        C   53  100  Not Diffused          [83]        1          [83]
# 12        C   13  100  Not Diffused  [44, 78, 83]        3  [44, 78, 83]
# 78        C   79  100      Resitant      [77, 85]        2          [77]
#
#    Num_Nbrs_Dffsd high_nbrs high_nbr_diff Deg_Ctrlty Probability ratio  \
# 25              0      [92]             1   0.010101    0.744165     0
# 95              1      [32]             1   0.010101   0.0948665     1
# 23              1      [14]             1   0.010101    0.586602     1
# 1               1      [51]             1   0.010101    0.754046     1
# 26              1      [77]             1   0.010101    0.762472     1
# 85              2       [4]             1   0.020202    0.883028     1
# 61              1      [86]             0   0.020202    0.898666   0.5
# 52              1      [83]             1   0.010101      0.8065     1
# 12              3  [78, 83]             1   0.030303    0.773527     1
# 78              1      [77]             1   0.020202   0.0887791   0.5
#
#      tcudorp  knar knar_norm
# 25   1.00427   NaN       NaN
# 95   1.35497   NaN       NaN
# 23    1.8467   NaN       NaN
# 1    2.01415  14.0  0.518519
# 26   2.02257  15.0  0.555556
# 85   2.15323   3.0  0.111111
# 61   1.41887   NaN       NaN
# 52    2.0666  18.0  0.666667
# 12   2.05383  17.0   0.62963
# 78  0.858981   NaN       NaN

# %%
df2A.sample(2)
# Out:
#    Behavior Node                Time                 min             lag  \
# 2         A    4 2016-01-06 02:44:17 2016-01-01 16:26:01 4 days 10:18:16
# 17        A   30 2016-01-06 12:41:41 2016-01-01 16:26:01 4 days 20:15:40
#
#     lag2     Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 2      4  [12, 99, 86]     0.030303             0.0            0      [12]
# 17     4      [19, 82]     0.020202             0.0            0  [19, 82]

# %%
df2A_trimmed = df2A
df2A_trimmed.drop(columns=['Time','min','lag','Neighbors','Deg_Cntrlty','relation','ratio'], inplace=True)
df2A_trimmed.sample(10)
# Out:
#    Behavior Node  lag2  inflncr_scr high_nbrs
# 18        A   31     4            0      [94]
# 5         A    9     1            0      [51]
# 20        A   33    10            0      [83]
# 9         A   15     2            0      [88]
# 46        A   89     5            0      [46]
# 41        A   77     1            0      [39]
# 54        A   99     2            0       [4]
# 42        A   80     4            0       [9]
# 34        A   60     3            0      [19]
# 32        A   56     2            0      [62]

# %%
df2B_Diff_Algo2_Trim = df2B_Diff_Algo2
df2B_Diff_Algo2_Trim.drop(columns=['Flag','Nbrs','Num_Nbrs','Nbrs_Dffsed','Num_Nbrs_Dffsd','Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm'], inplace=True)
df2B_Diff_Algo2_Trim.sample(5)
# Out:
#    Behavior Node Day high_nbrs high_nbr_diff
# 77        B   78   1      [51]             1
# 53        B   54   1      [92]             1
# 17        B   18   1      [39]             1
# 1         B    2   1      [51]             1
# 30        B   31   1      [94]             1

# %%
df2C_Diff_Algo2_Trim = df2C_Diff_Algo2
df2C_Diff_Algo2_Trim.drop(columns=['Flag','Nbrs','Num_Nbrs','Nbrs_Dffsed','Num_Nbrs_Dffsd','Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm'], inplace=True)
df2C_Diff_Algo2_Trim.sample(5)
# Out:
#    Behavior Node  Day high_nbrs high_nbr_diff
# 40        C   41    3      [75]             0
# 79        C   80    2       [9]             1
# 20        C   21    7      [51]             1
# 58        C   59  100      [61]             1
# 25        C   26    6      [92]             1

# %%
weights = pd.read_csv("C:/Users/sumith.singh/A_SUBEX/GOF_Weight.csv", index_col=False, header=0)
TP = (weights.loc[weights['Item'] == 'TruePositive', 'Weights'])
TN = (weights.loc[weights['Item'] == 'TrueNegative', 'Weights'])
FP = (weights.loc[weights['Item'] == 'FalsePositive', 'Weights'])
FN = (weights.loc[weights['Item'] == 'FalseNegative', 'Weights'])

#print('TP: ' (TP[0]))
#print('TN: ' str(TP))
#print('FP: ' str(TP))
#print('FN: ' str(TP))
weights
# Out:
#             Item  Weights
# 0   TruePositive      1.0
# 1   TrueNegative      2.0
# 2  FalsePositive      1.0
# 3  FalseNegative      0.5

# %%
# A is random Prediction
# B is actual
#C is weighted Prediction
df_GOF_BA = pd.merge(df2B_Diff_Algo2_Trim, df2A_trimmed, how='left', on=['Node'] )
df_GOF_BA['Behavior_y']=df_GOF_BA['Behavior_y'].fillna('A')
df_GOF_BA['lag2']=df_GOF_BA['lag2'].fillna(-1)
df_GOF_BA.rename(columns={'Day': 'weeks_act'}, inplace=True)
df_GOF_BA.rename(columns={'lag2': 'weeks_pred'}, inplace=True)
for i in range(len(df_GOF_BA)):
    if df_GOF_BA.weeks_act[i] == 100 :
        df_GOF_BA.weeks_act[i] = -1

for i in range(len(df_GOF_BA)):
    if df_GOF_BA.weeks_pred[i] == 100 :
        df_GOF_BA.weeks_pred[i] = -1 
        
df_GOF_BA.sample(10)
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#    Behavior_x Node weeks_act high_nbrs_x high_nbr_diff Behavior_y  weeks_pred  \
# 8           B    9         1        [51]             1          A         1.0
# 80          B   81         1        [83]             1          A        -1.0
# 36          B   37         1        [51]             1          A        -1.0
# 10          B   11         1        [42]             1          A        -1.0
# 72          B   73         1        [65]             1          A         3.0
# 50          B   51         1      [3, 9]             1          A         0.0
# 84          B   85         1        [79]             1          A         5.0
# 88          B   89         1        [46]             1          A         5.0
# 64          B   65         1        [73]             1          A        -1.0
# 59          B   60         1        [19]             1          A         3.0
#
#     inflncr_scr high_nbrs_y
# 8           0.0        [51]
# 80          NaN         NaN
# 36          NaN         NaN
# 10          NaN         NaN
# 72          0.0        [65]
# 50          0.0      [3, 9]
# 84          0.0        [79]
# 88          0.0        [46]
# 64          NaN         NaN
# 59          0.0        [19]

# %%
df_GOF_BC = pd.merge(df2B_Diff_Algo2_Trim, df2C_Diff_Algo2_Trim, how='left', on=['Node'] )
#df_GOF_BA['Behavior_y']=df_GOF_BA['Behavior_y'].fillna('A')
#df_GOF_BA['lag2']=df_GOF_BA['lag2'].fillna(-1)
df_GOF_BC.rename(columns={'Day_x': 'weeks_act'}, inplace=True)
df_GOF_BC.rename(columns={'Day_y': 'weeks_pred'}, inplace=True)
for i in range(len(df_GOF_BC)):
    if df_GOF_BC.weeks_act[i] == 100 :
        df_GOF_BC.weeks_act[i] = -1

for i in range(len(df_GOF_BC)):
    if df_GOF_BC.weeks_pred[i] == 100 :
        df_GOF_BC.weeks_pred[i] = -1        
df_GOF_BC.sample(10)
# Out:
#    Behavior_x Node weeks_act high_nbrs_x high_nbr_diff_x Behavior_y  \
# 14          B   15         1        [88]               1          C
# 25          B   26         1        [92]               1          C
# 0           B    1        -1        [68]               1          C
# 56          B   57         1        [58]               1          C
# 75          B   76         1        [51]               1          C
# 40          B   41         1        [75]               1          C
# 73          B   74         1        [39]               1          C
# 12          B   13         1    [78, 83]               1          C
# 21          B   22         1        [35]               1          C
# 59          B   60         1        [19]               1          C
#
#    weeks_pred high_nbrs_y high_nbr_diff_y
# 14          5        [88]               0
# 25          6        [92]               1
# 0           1        [68]               0
# 56          4        [58]               0
# 75         -1        [51]               1
# 40          3        [75]               0
# 73          4        [39]               0
# 12         -1    [78, 83]               1
# 21          4        [35]               0
# 59         -1        [19]               1

# %%
def check_overall2(df):
    if df['weeks_act'] < 0 :
        if df['weeks_pred'] < 0 :
            return 1#TN[1]
        else :
            return 1#FP[2]
    else :
        if df['weeks_pred'] >= 0 :
            return 2#TP[0]
        else :
            return 1#FN[3]

# %%
df_GOF_BC['check_numb'] = df_GOF_BC.apply(check_overall2, axis=1)

# %%
def check_overall(df):
    if df['weeks_act'] < 0 :
        if df['weeks_pred'] < 0 :
            return 'True Negative'
        else :
            return 'False Positive'
    else :
        if df['weeks_pred'] >= 0 :
            return 'True Positive'
        else :
            return 'False Negative'

# %%
df_GOF_BC['check'] = df_GOF_BC.apply(check_overall, axis=1)

# %%
def timeliness(df):
    if df['check'] == 'True Positive' :
        if df['weeks_act'] < df['weeks_pred']:
            return 'Predicted Late'
        elif df['weeks_act'] == df['weeks_pred']:
            return 'Perfect'
        else:
            return 'Predicted Early'

# %%
df_GOF_BC['Timeliness'] = df_GOF_BC.apply(timeliness, axis=1)
df_GOF_BC.sample(10)
# Out:
#    Behavior_x Node weeks_act high_nbrs_x high_nbr_diff_x Behavior_y  \
# 92          B   93         1        [42]               1          C
# 38          B   39         1        [77]               1          C
# 13          B   14         1        [24]               1          C
# 37          B   38         1        [83]               1          C
# 33          B   34         1        [78]               1          C
# 19          B   20         1        [21]               1          C
# 73          B   74         1        [39]               1          C
# 44          B   45         1        [54]               1          C
# 11          B   12         1         [4]               1          C
# 4           B    5         1         [3]               1          C
#
#    weeks_pred high_nbrs_y high_nbr_diff_y  check_numb           check  \
# 92         -1        [42]               1           1  False Negative
# 38         -1        [77]               1           1  False Negative
# 13          4        [24]               1           2   True Positive
# 37         -1        [83]               1           1  False Negative
# 33          4        [78]               1           2   True Positive
# 19         -1        [21]               1           1  False Negative
# 73          4        [39]               0           2   True Positive
# 44          5        [54]               1           2   True Positive
# 11         -1         [4]               1           1  False Negative
# 4           2         [3]               0           2   True Positive
#
#         Timeliness
# 92            None
# 38            None
# 13  Predicted Late
# 37            None
# 33  Predicted Late
# 19            None
# 73  Predicted Late
# 44  Predicted Late
# 11            None
# 4   Predicted Late

# %%
df_GOF_BC.check_numb.sum()
# Out:
# 165

# %%
df_GOF_BA['check'] = df_GOF_BA.apply(check_overall, axis=1)
df_GOF_BA['check_numb'] = df_GOF_BA.apply(check_overall2, axis=1)
df_GOF_BA.sample(10)
# Out:
#    Behavior_x Node weeks_act high_nbrs_x high_nbr_diff Behavior_y  weeks_pred  \
# 46          B   47         1         [3]             1          A         6.0
# 60          B   61         1        [59]             1          A        -1.0
# 27          B   28         1        [21]             1          A         0.0
# 16          B   17         1        [34]             1          A         9.0
# 72          B   73         1        [65]             1          A         3.0
# 56          B   57         1        [58]             1          A        -1.0
# 71          B   72         1        [43]             1          A        -1.0
# 74          B   75         1        [67]             1          A         9.0
# 52          B   53         1        [83]             1          A        -1.0
# 51          B   52         1        [99]             1          A         1.0
#
#     inflncr_scr high_nbrs_y           check  check_numb
# 46          0.0         [3]   True Positive           2
# 60          NaN         NaN  False Negative           1
# 27          0.0        [21]   True Positive           2
# 16          0.0        [34]   True Positive           2
# 72          0.0        [65]   True Positive           2
# 56          NaN         NaN  False Negative           1
# 71          NaN         NaN  False Negative           1
# 74          0.0        [67]   True Positive           2
# 52          NaN         NaN  False Negative           1
# 51          0.0        [99]   True Positive           2

# %%
df_GOF_BA.check_numb.sum()
# Out:
# 153

# %%
df_GOF_BA = df_GOF_BA.groupby('check').size()
df_GOF_BA
# Out:
# check
# False Negative    44
# False Positive     1
# True Positive     54
# dtype: int64

# %%
df_GOF_BA['False Positive']
# Out:
# 1

# %%
df_GOF_BC = df_GOF_BC.groupby('check').size()
df_GOF_BC
# Out:
# check
# False Negative    32
# False Positive     1
# True Positive     66
# dtype: int64

# %%
TP = df_GOF_BA['True Positive']
FP = df_GOF_BA['False Positive']
FN = df_GOF_BA['False Negative']
FP = df_GOF_BA['True Negative']
x = np.array([[TP, FP], \
                [FN,FP]])

row_labels = ['P Predicted', 'N Predicted']


print ("              AP   AN ")
for row_label, row in zip(row_labels, x):
    print ('%s [%s]' % (row_label, ' '.join('%03s' % i for i in row)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2565             try:
# -> 2566                 return libts.get_value_box(s, key)
#    2567             except IndexError:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-371b99b6f3fe> in <module>()
#       2 FP = df_GOF_BA['False Positive']
#       3 FN = df_GOF_BA['False Negative']
# ----> 4 FP = df_GOF_BA['True Negative']
#       5 x = np.array([[TP, FP],                 [FN,FP]])
#       6
#
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2572                     raise InvalidIndexError(key)
#    2573                 else:
# -> 2574                     raise e1
#    2575             except Exception:  # pragma: no cover
#    2576                 raise e1
#
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'True Negative'

# %% [markdown]
# ## Within 2 Weeks Influencer

# %%
def realtion(dfx):
    b=[]
    for j in range(len(dfx)):
        i=0
        a=[]
        for i in range(len(dfx.Neighbors[j])):
            #print(dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values,"\t",dfx.lag2[dfx.Node==dfx.Node[j]].values)
            if dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values<dfx.lag2[dfx.Node==dfx.Node[j]].values:
                a.append(dfx.Neighbors[j][i])
        dfx['relation'][j]=a
        dfx['ratio'][j] = len(a)/len(dfx.Neighbors[j])
    return dfx

# %%
df2A.sample(2)
