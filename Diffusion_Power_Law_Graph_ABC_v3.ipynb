# %% [markdown]
# ### A - Random Diffusion Behavior
# ### B - Algo1 Diffusion Behavior
# ### C - Algo1 Diffusion Behavior

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import networkx as nx
import os
#import nxviz as nv
os.getcwd()
# Out:
# 'C:\\Users\\sumith.singh\\A_SUBEX'

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# # Graph Generation

# %%
n =  100 # number of nodes
nodes = list(range(1,n))

# %%
while True:  
    s=[]
    while len(s)<n:
        nextval = int(nx.utils.powerlaw_sequence(1, 2.5)[0]) #100 nodes, power-law exponent 2.5
        if nextval!=0:
            s.append(nextval)
    if sum(s)%2 == 0:
        break
G = nx.configuration_model(s)
G=nx.Graph(G) # remove parallel edges
G.remove_edges_from(G.selfloop_edges())

# %%
nx.draw(G)
plt.show()
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos)
plt.show()

# %%
#list(G.nodes())

# %%
# Graph Properties
print('Edges -- ')
print(G.edges())
print('Neighbors--')
print(G.neighbors(2))
print('Degree Centrality')
print(nx.degree_centrality(G))
#print('Graph')
#print(G)
# Out:
# Edges --
# [(0, 74), (1, 98), (1, 8), (2, 14), (3, 63), (4, 29), (5, 74), (5, 44), (6, 96), (7, 74), (8, 14), (8, 19), (8, 81), (9, 62), (9, 37), (9, 74), (9, 80), (10, 74), (11, 22), (11, 69), (12, 74), (13, 46), (14, 74), (14, 22), (14, 57), (15, 33), (16, 44), (17, 44), (18, 73), (18, 34), (20, 85), (21, 62), (22, 97), (22, 93), (22, 38), (22, 44), (22, 74), (22, 29), (22, 79), (22, 48), (22, 86), (22, 95), (22, 65), (22, 60), (22, 37), (22, 56), (22, 59), (22, 99), (22, 40), (22, 69), (22, 28), (22, 39), (22, 71), (22, 66), (23, 74), (24, 53), (25, 38), (25, 49), (25, 95), (26, 37), (26, 43), (27, 81), (28, 63), (29, 44), (30, 56), (31, 34), (31, 91), (32, 42), (32, 74), (34, 35), (36, 74), (37, 74), (37, 95), (37, 52), (37, 44), (37, 86), (37, 63), (37, 72), (37, 83), (37, 51), (38, 84), (38, 75), (38, 74), (38, 41), (40, 74), (42, 74), (44, 56), (44, 53), (44, 64), (44, 77), (44, 47), (44, 65), (45, 72), (47, 74), (47, 69), (50, 62), (50, 92), (54, 68), (55, 77), (56, 58), (56, 90), (57, 82), (61, 99), (63, 74), (63, 88), (65, 74), (65, 98), (67, 78), (67, 74), (69, 94), (69, 74), (70, 74), (74, 92), (74, 87), (74, 81), (74, 89), (74, 94), (74, 76), (74, 95)]
# Neighbors--
# [14]
# Degree Centrality
# {0: 0.010101010101010102, 1: 0.020202020202020204, 2: 0.010101010101010102, 3: 0.010101010101010102, 4: 0.010101010101010102, 5: 0.020202020202020204, 6: 0.010101010101010102, 7: 0.010101010101010102, 8: 0.04040404040404041, 9: 0.04040404040404041, 10: 0.010101010101010102, 11: 0.020202020202020204, 12: 0.010101010101010102, 13: 0.010101010101010102, 14: 0.05050505050505051, 15: 0.010101010101010102, 16: 0.010101010101010102, 17: 0.010101010101010102, 18: 0.020202020202020204, 19: 0.010101010101010102, 20: 0.010101010101010102, 21: 0.010101010101010102, 22: 0.24242424242424243, 23: 0.010101010101010102, 24: 0.010101010101010102, 25: 0.030303030303030304, 26: 0.020202020202020204, 27: 0.010101010101010102, 28: 0.020202020202020204, 29: 0.030303030303030304, 30: 0.010101010101010102, 31: 0.020202020202020204, 32: 0.020202020202020204, 33: 0.010101010101010102, 34: 0.030303030303030304, 35: 0.010101010101010102, 36: 0.010101010101010102, 37: 0.12121212121212122, 38: 0.06060606060606061, 39: 0.010101010101010102, 40: 0.020202020202020204, 41: 0.010101010101010102, 42: 0.020202020202020204, 43: 0.010101010101010102, 44: 0.12121212121212122, 45: 0.010101010101010102, 46: 0.010101010101010102, 47: 0.030303030303030304, 48: 0.010101010101010102, 49: 0.010101010101010102, 50: 0.020202020202020204, 51: 0.010101010101010102, 52: 0.010101010101010102, 53: 0.020202020202020204, 54: 0.010101010101010102, 55: 0.010101010101010102, 56: 0.05050505050505051, 57: 0.020202020202020204, 58: 0.010101010101010102, 59: 0.010101010101010102, 60: 0.010101010101010102, 61: 0.010101010101010102, 62: 0.030303030303030304, 63: 0.05050505050505051, 64: 0.010101010101010102, 65: 0.04040404040404041, 66: 0.010101010101010102, 67: 0.020202020202020204, 68: 0.010101010101010102, 69: 0.05050505050505051, 70: 0.010101010101010102, 71: 0.010101010101010102, 72: 0.020202020202020204, 73: 0.010101010101010102, 74: 0.2828282828282829, 75: 0.010101010101010102, 76: 0.010101010101010102, 77: 0.020202020202020204, 78: 0.010101010101010102, 79: 0.010101010101010102, 80: 0.010101010101010102, 81: 0.030303030303030304, 82: 0.010101010101010102, 83: 0.010101010101010102, 84: 0.010101010101010102, 85: 0.010101010101010102, 86: 0.020202020202020204, 87: 0.010101010101010102, 88: 0.010101010101010102, 89: 0.010101010101010102, 90: 0.010101010101010102, 91: 0.010101010101010102, 92: 0.020202020202020204, 93: 0.010101010101010102, 94: 0.020202020202020204, 95: 0.04040404040404041, 96: 0.010101010101010102, 97: 0.010101010101010102, 98: 0.020202020202020204, 99: 0.020202020202020204}

# %%
max_nbrs = 0
max_node = 0
for element in G.nodes():
    #print(element, len(G.neighbors(element)) )
    if len(G.neighbors(element)) > max_nbrs:
        max_nbrs = len(G.neighbors(element))
        max_node = element
print("The node with maximum number of neighbor is: ", max_node)
print("The neighbors are: ", G.neighbors(max_node))
print("The number of neighbors is: ", len(G.neighbors(max_node)))
# Out:
# The node with maximum number of neighbor is:  74
# The neighbors are:  [0, 5, 7, 9, 10, 12, 14, 22, 23, 32, 36, 37, 38, 40, 42, 47, 63, 65, 67, 69, 70, 92, 87, 81, 89, 94, 76, 95]
# The number of neighbors is:  28

# %%
nx.set_node_attributes(G,'degree_cent',nx.degree_centrality(G))

# %% [markdown]
# #### degrees = [len(G.neighbors(n)) for n in G.nodes()]
# deg_cent = nx.degree_centrality(G)
# plt.hist(list(deg_cent.values()))
# plt.show()

# %%
plt.hist(degrees)
plt.show()

# %%
plt.scatter(degrees, list(deg_cent.values()))
plt.show()

# %%
from random import randrange
from datetime import timedelta
import datetime

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
d1A = datetime.datetime.strptime('1/1/2016 1:30 PM', '%m/%d/%Y %I:%M %p')
d2A = datetime.datetime.strptime('1/13/2016 4:50 AM', '%m/%d/%Y %I:%M %p')
d1B = datetime.datetime.strptime('3/1/2017 1:30 PM', '%m/%d/%Y %I:%M %p')
d2B = datetime.datetime.strptime('3/13/2017 4:50 AM', '%m/%d/%Y %I:%M %p')
d1C = datetime.datetime.strptime('5/1/2018 1:30 PM', '%m/%d/%Y %I:%M %p')
d2C = datetime.datetime.strptime('5/13/2018 4:50 AM', '%m/%d/%Y %I:%M %p')
print(random_date(d1A, d2A))
# Out:
# 2016-01-10 02:20:23

# %%
len(nodes)
# Out:
# 99

# %%
nodes[98]
# Out:
# 99

# %% [markdown]
# # First DF Creation

# %%
traits = ['A','B','C']
cols = ['Sequence','Behavior', 'Node', 'Time', 'Prob']
df2 = pd.DataFrame(columns=cols, index=range((len(traits)*len(nodes))))   # 100 need not be put in a afile. It will be modified once we have an external data source
for a in range(len(traits)*len(nodes)):
    df2.loc[a].Sequence = 1
    df2.loc[a].Behavior = 'A'
    df2.loc[a].Node = 5
    df2.loc[a].Time = datetime.datetime.strptime('1/1/2018 1:30 PM', '%m/%d/%Y %I:%M %p')
    df2.loc[a].Prob = 0.00001
#df2

# %%
k = 0
for i in traits:
    k = k + 1
    #print("Outer")
    for j in nodes:
        #Behav_Time = [random_date(d1,d2) for k in range(len(nodes)+1)]
        Behav_Prob = [np.random.random() for i in range(len(nodes)+1)]
        #bhv_prb = np.random.random()
        order = ((k-1)*len(nodes)+j)
        a = order - 1
        #data = dict(zip(Behav_Time[j],round(Behav_Prob[j],2)))
        df2.loc[a].Sequence = a+1
        df2.loc[a].Behavior = i
        df2.loc[a].Node = j
        if i == 'A' :
            df2.loc[a].Time = random_date(d1A,d2A)
        elif i == 'B' :
            df2.loc[a].Time = random_date(d1B,d2B)
        else :
            df2.loc[a].Time = random_date(d1C,d2C)
        df2.loc[a].Prob = round(Behav_Prob[j],2)
        #print(order,i,j,Behav_Time[j],round(Behav_Prob[j],2) )
       # new_df[order-1] = ['A', 1, '20-06-2018', 0.32]
print(order)
# Out:
# 297

# %%
df2.sample(5)
# Out:
#     Sequence Behavior Node                 Time  Prob
# 182      183        B   84  2017-03-09 03:31:00  0.45
# 156      157        B   58  2017-03-02 09:44:22  0.64
# 254      255        C   57  2018-05-07 23:24:53  0.11
# 239      240        C   42  2018-05-05 17:41:39     0
# 160      161        B   62  2017-03-04 05:42:48  0.91

# %%
df2.Behavior.unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df2 = df2.drop(df2[df2.Behavior != 'A'].index)
df2.sample(5)
# Out:
#    Sequence Behavior Node                 Time  Prob
# 22       23        A   23  2016-01-05 19:28:02  0.88
# 93       94        A   94  2016-01-10 11:36:09  0.52
# 20       21        A   21  2016-01-04 06:34:45  0.54
# 16       17        A   17  2016-01-06 22:43:05  0.99
# 33       34        A   34  2016-01-12 19:25:49  0.06

# %%
df2.Behavior.unique()
# Out:
# array(['A'], dtype=object)

# %%
df2 = df2.drop(df2[df2.Prob < 0.5].index)

# %%
range(df2.shape[1])
df2.shape
# Out:
# (51, 5)

# %%
df2 = df2.drop('Sequence',axis=1)
df2 = df2.drop('Prob',axis=1)

# %%
df2.reset_index(inplace=True)
df2.drop(columns='index', inplace=True)
df2.head()
# Out:
#   Behavior Node                 Time
# 0        A    4  2016-01-05 21:09:25
# 1        A    5  2016-01-03 08:31:22
# 2        A    6  2016-01-05 08:48:34
# 3        A    8  2016-01-08 07:12:12
# 4        A    9  2016-01-10 02:00:38

# %%
#df2.dtypes

# %%
df3 = df2.groupby('Behavior')['Time'].min()
df3
# Out:
# Behavior
# A   2016-01-01 16:56:43
# Name: Time, dtype: datetime64[ns]

# %%
print("A:" + str(df3['A']))
#print('B:' + str(df3['B']))
#print('C:' + str(df3['C']))
# Out:
# A:2016-01-01 16:56:43

# %%
def get_min(df):
    if df['Behavior'] == 'A' :
        return df3['A']
    elif df['Behavior'] == 'B' :
        return df3['B']
    else :
        return df3['C']

# %%
df2['min'] = df2.apply(get_min, axis=1)
df2['Time'] =  pd.to_datetime(df2['Time'], format='%m/%d/%Y %I:%M %p')
print(df2.info())
df2.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
# Behavior    51 non-null object
# Node        51 non-null object
# Time        51 non-null datetime64[ns]
# min         51 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 1.7+ KB
# None
#    Behavior Node                Time                 min
# 37        A   77 2016-01-05 02:28:04 2016-01-01 16:56:43
# 14        A   33 2016-01-12 21:52:50 2016-01-01 16:56:43
# 32        A   67 2016-01-12 11:48:21 2016-01-01 16:56:43
# 29        A   61 2016-01-04 02:28:33 2016-01-01 16:56:43
# 26        A   58 2016-01-07 09:50:42 2016-01-01 16:56:43

# %% [markdown]
# # Lag Creation

# %%
#df2['Time'] =  pd.to_datetime(df2['Time'], format='%d%b%Y:%H:%M:%S.%f')
df2['lag'] = (df2['Time'] - df2['min'])
df2['lag2'] = 0
df2.reset_index(inplace=True)
df2.drop(columns='index', inplace=True)
for i in range(len(df2)):
    df2.lag2[i] = (df2.loc[i].lag.days)
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# # Neighbors & Degree Centrality Creation

# %%
df2['Neighbors'] = ''
df2['Deg_Cntrlty'] = 0.0
for i in range(len(df2)):
    df2.Neighbors[i] = G.neighbors(df2.loc[i].Node)
    df2.Deg_Cntrlty[i] = nx.degree_centrality(G)[df2.loc[i].Node]
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#nx.degree_centrality(G)
#nx.degree_centrality(G)[4]

# %%
#df2.drop(columns = ['level_0','index'], inplace=True)

# %%
df2.head()
# Out:
#   Behavior Node                Time                 min             lag  lag2  \
# 0        A    4 2016-01-05 21:09:25 2016-01-01 16:56:43 4 days 04:12:42     4
# 1        A    5 2016-01-03 08:31:22 2016-01-01 16:56:43 1 days 15:34:39     1
# 2        A    6 2016-01-05 08:48:34 2016-01-01 16:56:43 3 days 15:51:51     3
# 3        A    8 2016-01-08 07:12:12 2016-01-01 16:56:43 6 days 14:15:29     6
# 4        A    9 2016-01-10 02:00:38 2016-01-01 16:56:43 8 days 09:03:55     8
#
#           Neighbors  Deg_Cntrlty
# 0              [29]     0.010101
# 1          [74, 44]     0.020202
# 2              [96]     0.010101
# 3   [1, 14, 19, 81]     0.040404
# 4  [62, 37, 74, 80]     0.040404

# %% [markdown]
# # Friends, Relations & Influencer Score

# %%
df2['relation']=''
df2['ratio']=0.0
df2['inflncr_scr'] = 0
df2['high_nbrs'] = ''

# %%
def realtion(dfx):
    b=[]
    for j in range(len(dfx)):
        i=0
        a=[]
        for i in range(len(dfx.Neighbors[j])):
            #print(dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values,"\t",dfx.lag2[dfx.Node==dfx.Node[j]].values)
            if dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values<dfx.lag2[dfx.Node==dfx.Node[j]].values:
                a.append(dfx.Neighbors[j][i])
        dfx['relation'][j]=a
        dfx['ratio'][j] = len(a)/len(dfx.Neighbors[j])
    return dfx

# %%
df2[df2.Deg_Cntrlty > 0.].sample(5)
# Out:
#    Behavior Node                Time                 min             lag  \
# 9         A   23 2016-01-05 19:28:02 2016-01-01 16:56:43 4 days 02:31:19
# 34        A   70 2016-01-07 09:57:18 2016-01-01 16:56:43 5 days 17:00:35
# 23        A   54 2016-01-08 07:17:53 2016-01-01 16:56:43 6 days 14:21:10
# 24        A   55 2016-01-05 03:12:52 2016-01-01 16:56:43 3 days 10:16:09
# 40        A   82 2016-01-08 14:11:51 2016-01-01 16:56:43 6 days 21:15:08
#
#     lag2 Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 9      4      [74]     0.010101             0.0            0
# 34     5      [74]     0.010101             0.0            0
# 23     6      [68]     0.010101             0.0            0
# 24     3      [77]     0.010101             0.0            0
# 40     6      [57]     0.010101             0.0            0

# %%
def high_nbrs(dfx):
    for j in range(len(dfx)):
        str_nbrs = []
        max_nbr = 0
        max_deg = 0
        for i in G.neighbors(dfx.loc[j].Node):
            #print(i)
            if nx.degree_centrality(G)[i] >= max_deg:
                #print(nx.degree_centrality(G)[i])
                if nx.degree_centrality(G)[i] > max_deg:
                    str_nbrs = []
                    str_nbrs.append(i)
                    max_deg = nx.degree_centrality(G)[i]
                    max_nbr = i
                else:
                    str_nbrs.append(i)
        dfx['high_nbrs'][j] = str_nbrs
    return dfx

# %%
df2A = df2[df2.Behavior=='A']
#df2B = df2[df2.Behavior=='B']
#df2C = df2[df2.Behavior=='C']

# %%
df2A.reset_index(inplace=True)
df2A.drop(columns='index', inplace=True)
#df2B.reset_index(inplace=True)
#df2B.drop(columns='index', inplace=True)
#df2C.reset_index(inplace=True)
#df2C.drop(columns='index', inplace=True)

# %%
#df2A = realtion(df2A)
#df2B = realtion(df2B)
#df2C = realtion(df2C)
df2A.sample(5)
# Out:
#    Behavior Node                Time                 min              lag  \
# 47        A   93 2016-01-06 08:02:58 2016-01-01 16:56:43  4 days 15:06:15
# 28        A   60 2016-01-12 14:53:10 2016-01-01 16:56:43 10 days 21:56:27
# 20        A   48 2016-01-07 04:36:13 2016-01-01 16:56:43  5 days 11:39:30
# 11        A   30 2016-01-06 07:17:25 2016-01-01 16:56:43  4 days 14:20:42
# 18        A   42 2016-01-05 13:56:05 2016-01-01 16:56:43  3 days 20:59:22
#
#     lag2 Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 47     4      [22]     0.010101             0.0            0
# 28    10      [22]     0.010101             0.0            0
# 20     5      [22]     0.010101             0.0            0
# 11     4      [56]     0.010101             0.0            0
# 18     3  [32, 74]     0.020202             0.0            0

# %%
df2A = high_nbrs(df2A)
df2A.sample(5)
# Out:
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Behavior Node                Time                 min             lag  \
# 21        A   51 2016-01-10 22:27:16 2016-01-01 16:56:43 9 days 05:30:33
# 49        A   96 2016-01-06 02:24:44 2016-01-01 16:56:43 4 days 09:28:01
# 23        A   54 2016-01-08 07:17:53 2016-01-01 16:56:43 6 days 14:21:10
# 45        A   91 2016-01-10 17:00:47 2016-01-01 16:56:43 9 days 00:04:04
# 9         A   23 2016-01-05 19:28:02 2016-01-01 16:56:43 4 days 02:31:19
#
#     lag2 Neighbors  Deg_Cntrlty relation  ratio  inflncr_scr high_nbrs
# 21     9      [37]     0.010101             0.0            0      [37]
# 49     4       [6]     0.010101             0.0            0       [6]
# 23     6      [68]     0.010101             0.0            0      [68]
# 45     9      [31]     0.010101             0.0            0      [31]
# 9      4      [74]     0.010101             0.0            0      [74]

# %%
cliques = nx.find_cliques(G)
list(cliques)

# %% [markdown]
#  # Alternate Algorithm for Behavior Generation

# %%
def realtion(dfx):
    b=[]
    for j in range(len(dfx)):
        i=0
        a=[]
        for i in range(len(dfx.Nbrs[j])):
            #print(dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values,"\t",dfx.lag2[dfx.Node==dfx.Node[j]].values)
            if dfx.Day[dfx.Node==dfx.Nbrs[j][i]].values<dfx.Day[dfx.Node==dfx.Node[j]].values:
                a.append(dfx.Nbrs[j][i])
        dfx['Nbrs_Dffsed'][j]=a
        dfx['Num_Nbrs_Dffsd'][j]=len(a)
        dfx['ratio'][j] = len(a)/len(dfx.Nbrs[j])
    return dfx

# %%
def high_diffsd(dfx):
    y = 0
    for j in range(len(dfx)):
        i = 0
        y = 0
        for i in range(len(dfx.high_nbrs[j])):
            print("j is: ", j)
            print("i is: ", i)
            print("dfx.high_nbrs[j][i] node is, ", dfx.high_nbrs[j][i] )
            print("The status of it", dfx.Flag[dfx.Node == dfx.high_nbrs[j][i]])
            k = dfx.Flag[dfx.Node == dfx.high_nbrs[j][i]]
            print("k is, check here", k )
            #if (k == 'Diffused'):
            print("YESSSSSSS")       
            y = 1
        dfx['high_nbr_diff'][j] = y
    return dfx

# %%
k = 'Diffused'
if (k == 'Diffused'):
    print("Y")
# Out:
# Y

# %%
def high_diffsd(dfx):
    y = 0
    for j in range(len(dfx)):
        i = 0
        y = 0
        for i in range(len(dfx.high_nbrs[j])):
            if dfx.Flag[dfx.Node == dfx.high_nbrs[j][i]] == 'Diffused':
                y = 1
        dfx['high_nbr_diff'][j] = y
    return dfx

# %%
cols = ['Behavior', 'Node','Day', 'Flag','Nbrs', 'Num_Nbrs','Nbrs_Dffsed', 'Num_Nbrs_Dffsd','high_nbrs','high_nbr_diff',
        'Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm']
df2B_Diff_Algo2 = pd.DataFrame(columns=cols, index=range(len(nodes)))   # 100 need not be put in a afile. It will be modified once we have an external data source
for a in range(len(nodes)):
    df2B_Diff_Algo2.loc[a].Behavior = 'B'
    df2B_Diff_Algo2.loc[a].Node = nodes[a]
    df2B_Diff_Algo2.loc[a].Day = 100
    df2B_Diff_Algo2.loc[a].Flag = 'Not Diffused'
    #print(nodes[a])
    df2B_Diff_Algo2.loc[a].Nbrs = ''
    df2B_Diff_Algo2.loc[a].Num_Nbrs = 0
    df2B_Diff_Algo2.loc[a].Nbrs_Dffsed = ''
    df2B_Diff_Algo2.loc[a].Num_Nbrs_Dffsd = 0
    df2B_Diff_Algo2.loc[a].high_nbrs = [] 
    df2B_Diff_Algo2.loc[a].high_nbr_diff = 0
    df2B_Diff_Algo2.loc[a].Deg_Ctrlty = 0.0
    df2B_Diff_Algo2.loc[a].Probability = 0.0
    df2B_Diff_Algo2.loc[a].ratio = 0.0
    df2B_Diff_Algo2.loc[a].tcudorp = 0.0
    df2B_Diff_Algo2.loc[a].knar = 0
    df2B_Diff_Algo2.loc[a].knar_norm = 0

#df2C_Diff_Algo2
for i in range(len(df2B_Diff_Algo2)):
    df2B_Diff_Algo2.Nbrs[i] = G.neighbors(df2B_Diff_Algo2.loc[i].Node)
    df2B_Diff_Algo2.Deg_Ctrlty[i] = nx.degree_centrality(G)[df2B_Diff_Algo2.loc[i].Node]
for i in range(len(df2B_Diff_Algo2)):
    df2B_Diff_Algo2.Num_Nbrs[i] = len(df2B_Diff_Algo2.Nbrs[i])
    df2B_Diff_Algo2.Num_Nbrs_Dffsd[i] = len(df2B_Diff_Algo2.Nbrs_Dffsed[i])
    df2B_Diff_Algo2.Probability[i] = np.random.random()
    if df2B_Diff_Algo2.Probability[i] < 0.1:
        df2B_Diff_Algo2.Flag[i] = 'Resitant'
    if df2B_Diff_Algo2.Probability[i] > 0.9:
        df2B_Diff_Algo2.Flag[i] = 'Diffused'
        df2B_Diff_Algo2.Day[i] = 1

# %%
cols = ['Behavior', 'Node','Day', 'Flag','Nbrs', 'Num_Nbrs','Nbrs_Dffsed', 'Num_Nbrs_Dffsd', 'high_nbrs','high_nbr_diff', 
        'Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm']
df2C_Diff_Algo2 = pd.DataFrame(columns=cols, index=range(len(nodes)))   # 100 need not be put in a afile. It will be modified once we have an external data source
for a in range(len(nodes)):
    df2C_Diff_Algo2.loc[a].Behavior = 'C'
    df2C_Diff_Algo2.loc[a].Node = nodes[a]
    df2C_Diff_Algo2.loc[a].Day = 100
    df2C_Diff_Algo2.loc[a].Flag = 'Not Diffused'
    #print(nodes[a])
    df2C_Diff_Algo2.loc[a].Nbrs = ''
    df2C_Diff_Algo2.loc[a].Num_Nbrs = 0
    df2C_Diff_Algo2.loc[a].Nbrs_Dffsed = ''
    df2C_Diff_Algo2.loc[a].Num_Nbrs_Dffsd = 0
    df2C_Diff_Algo2.loc[a].high_nbrs = [] 
    df2C_Diff_Algo2.loc[a].high_nbr_diff = 0
    df2C_Diff_Algo2.loc[a].Deg_Ctrlty = 0.0
    df2C_Diff_Algo2.loc[a].Probability = 0.0
    df2C_Diff_Algo2.loc[a].ratio = 0.0
    df2C_Diff_Algo2.loc[a].tcudorp = 0.0
    df2C_Diff_Algo2.loc[a].knar = 0
    df2C_Diff_Algo2.loc[a].knar_norm = 0

#df2C_Diff_Algo2
for i in range(len(df2C_Diff_Algo2)):
    df2C_Diff_Algo2.Nbrs[i] = G.neighbors(df2C_Diff_Algo2.loc[i].Node)
    df2C_Diff_Algo2.Deg_Ctrlty[i] = nx.degree_centrality(G)[df2C_Diff_Algo2.loc[i].Node]
for i in range(len(df2C_Diff_Algo2)):
    df2C_Diff_Algo2.Num_Nbrs[i] = len(df2C_Diff_Algo2.Nbrs[i])
    df2C_Diff_Algo2.Num_Nbrs_Dffsd[i] = len(df2C_Diff_Algo2.Nbrs_Dffsed[i])
    df2C_Diff_Algo2.Probability[i] = np.random.random()
    if df2C_Diff_Algo2.Probability[i] < 0.1:
        df2C_Diff_Algo2.Flag[i] = 'Resitant'
    if df2C_Diff_Algo2.Probability[i] > 0.9:
        df2C_Diff_Algo2.Flag[i] = 'Diffused'
        df2C_Diff_Algo2.Day[i] = 1

# %%
df2B_Diff_Algo2 = high_nbrs(df2B_Diff_Algo2)
df2B_Diff_Algo2.sample(5)
# Out:
#    Behavior Node  Day          Flag         Nbrs Num_Nbrs Nbrs_Dffsed  \
# 40        B   41  100  Not Diffused         [38]        1
# 28        B   29  100  Not Diffused  [4, 22, 44]        3
# 5         B    6  100  Not Diffused         [96]        1
# 71        B   72  100  Not Diffused     [37, 45]        2
# 23        B   24  100  Not Diffused         [53]        1
#
#    Num_Nbrs_Dffsd high_nbrs high_nbr_diff Deg_Ctrlty Probability ratio  \
# 40              0      [38]             0   0.010101    0.697921     0
# 28              0      [22]             0   0.030303    0.718669     0
# 5               0      [96]             0   0.010101    0.144698     0
# 71              0      [37]             0   0.020202    0.687911     0
# 23              0      [53]             0   0.010101    0.509276     0
#
#    tcudorp knar knar_norm
# 40       0    0         0
# 28       0    0         0
# 5        0    0         0
# 71       0    0         0
# 23       0    0         0

# %%
df2C_Diff_Algo2 = high_nbrs(df2C_Diff_Algo2)
df2C_Diff_Algo2.sample(5)
# Out:
#    Behavior Node  Day          Flag      Nbrs Num_Nbrs Nbrs_Dffsed  \
# 72        C   73  100  Not Diffused      [18]        1
# 31        C   32  100  Not Diffused  [42, 74]        2
# 86        C   87    1      Diffused      [74]        1
# 41        C   42    1      Diffused  [32, 74]        2
# 50        C   51  100      Resitant      [37]        1
#
#    Num_Nbrs_Dffsd high_nbrs high_nbr_diff Deg_Ctrlty Probability ratio  \
# 72              0      [18]             0   0.010101    0.550915     0
# 31              0      [74]             0   0.020202    0.733778     0
# 86              0      [74]             0   0.010101    0.973808     0
# 41              0      [74]             0   0.020202    0.942158     0
# 50              0      [37]             0   0.010101   0.0458107     0
#
#    tcudorp knar knar_norm
# 72       0    0         0
# 31       0    0         0
# 86       0    0         0
# 41       0    0         0
# 50       0    0         0

# %%
#df2C_Diff_Algo2

# %%
import time
start = time.time()
NumDays = 10
for j in (range(1, NumDays)):
    print("j is days and j is :" + str(j))
    #df2B_Diff_Algo2 = realtion(df2B_Diff_Algo2)
    print("The check is from here")
    df2B_Diff_Algo2 = high_diffsd(df2B_Diff_Algo2)
    print("Till here")
    todivide = len(df2B_Diff_Algo2) - df2B_Diff_Algo2.knar.isnull().sum()
    df2B_Diff_Algo2['knar'] = df2B_Diff_Algo2.tcudorp[df2B_Diff_Algo2['Flag']=='Not Diffused'].rank(ascending=True)
    for i in range(len(df2B_Diff_Algo2)):
        print("I am inside loop 1 & i is: "+ str(i))
        df2B_Diff_Algo2.tcudorp[i] = df2B_Diff_Algo2.ratio[i]*df2B_Diff_Algo2.Deg_Ctrlty[i]*df2B_Diff_Algo2.Probability[i]
        df2B_Diff_Algo2.knar_norm[i] = df2B_Diff_Algo2.knar[i]/todivide
    for i in range(len(df2B_Diff_Algo2)):
        print("I am inside loop 2 & new i is :"+ str(i))
        if(df2B_Diff_Algo2.knar_norm[i]<0.15):
            print("do i ever come here? " + str(i))
            df2B_Diff_Algo2.Flag[i] = 'Diffused'
            df2B_Diff_Algo2.Day[i] = j
end = time.time()
print(end-start)
# Out:
# j is days and j is :1
# The check is from here
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  8
# The status of it 7    Not Diffused
# Name: Flag, dtype: object
# k is, check here 7    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  63
# The status of it 62    Not Diffused
# Name: Flag, dtype: object
# k is, check here 62    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  29
# The status of it 28    Not Diffused
# Name: Flag, dtype: object
# k is, check here 28    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it 95    Not Diffused
# Name: Flag, dtype: object
# k is, check here 95    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it 45    Not Diffused
# Name: Flag, dtype: object
# k is, check here 45    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  33
# The status of it 32    Diffused
# Name: Flag, dtype: object
# k is, check here 32    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it 33    Not Diffused
# Name: Flag, dtype: object
# k is, check here 33    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  8
# The status of it 7    Not Diffused
# Name: Flag, dtype: object
# k is, check here 7    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  85
# The status of it 84    Not Diffused
# Name: Flag, dtype: object
# k is, check here 84    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it 61    Diffused
# Name: Flag, dtype: object
# k is, check here 61    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  53
# The status of it 52    Diffused
# Name: Flag, dtype: object
# k is, check here 52    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  81
# The status of it 80    Resitant
# Name: Flag, dtype: object
# k is, check here 80    Resitant
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it 33    Not Diffused
# Name: Flag, dtype: object
# k is, check here 33    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it 14    Not Diffused
# Name: Flag, dtype: object
# k is, check here 14    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  18
# The status of it 17    Not Diffused
# Name: Flag, dtype: object
# k is, check here 17    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  33
# i is:  1
# dfx.high_nbrs[j][i] node is,  31
# The status of it 30    Not Diffused
# Name: Flag, dtype: object
# k is, check here 30    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it 33    Not Diffused
# Name: Flag, dtype: object
# k is, check here 33    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  26
# The status of it 25    Not Diffused
# Name: Flag, dtype: object
# k is, check here 25    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it 71    Not Diffused
# Name: Flag, dtype: object
# k is, check here 71    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it 12    Not Diffused
# Name: Flag, dtype: object
# k is, check here 12    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  25
# The status of it 24    Not Diffused
# Name: Flag, dtype: object
# k is, check here 24    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it 61    Diffused
# Name: Flag, dtype: object
# k is, check here 61    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it 67    Not Diffused
# Name: Flag, dtype: object
# k is, check here 67    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it 76    Not Diffused
# Name: Flag, dtype: object
# k is, check here 76    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it 98    Not Diffused
# Name: Flag, dtype: object
# k is, check here 98    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it 8    Not Diffused
# Name: Flag, dtype: object
# k is, check here 8    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it 53    Not Diffused
# Name: Flag, dtype: object
# k is, check here 53    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  18
# The status of it 17    Not Diffused
# Name: Flag, dtype: object
# k is, check here 17    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it 66    Not Diffused
# Name: Flag, dtype: object
# k is, check here 66    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it 8    Not Diffused
# Name: Flag, dtype: object
# k is, check here 8    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  57
# The status of it 56    Not Diffused
# Name: Flag, dtype: object
# k is, check here 56    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  20
# The status of it 19    Diffused
# Name: Flag, dtype: object
# k is, check here 19    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  63
# The status of it 62    Not Diffused
# Name: Flag, dtype: object
# k is, check here 62    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it 30    Not Diffused
# Name: Flag, dtype: object
# k is, check here 30    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  6
# The status of it 5    Not Diffused
# Name: Flag, dtype: object
# k is, check here 5    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it 64    Not Diffused
# Name: Flag, dtype: object
# k is, check here 64    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# Till here
# I am inside loop 1 & i is: 0
# I am inside loop 1 & i is: 1
# I am inside loop 1 & i is: 2
# I am inside loop 1 & i is: 3
# I am inside loop 1 & i is: 4
# I am inside loop 1 & i is: 5
# I am inside loop 1 & i is: 6
# I am inside loop 1 & i is: 7
# I am inside loop 1 & i is: 8
# I am inside loop 1 & i is: 9
# I am inside loop 1 & i is: 10
# I am inside loop 1 & i is: 11
# I am inside loop 1 & i is: 12
# I am inside loop 1 & i is: 13
# I am inside loop 1 & i is: 14
# I am inside loop 1 & i is: 15
# I am inside loop 1 & i is: 16
# I am inside loop 1 & i is: 17
# I am inside loop 1 & i is: 18
# I am inside loop 1 & i is: 19
# I am inside loop 1 & i is: 20
# I am inside loop 1 & i is: 21
# I am inside loop 1 & i is: 22
# I am inside loop 1 & i is: 23
# I am inside loop 1 & i is: 24
# I am inside loop 1 & i is: 25
# I am inside loop 1 & i is: 26
# I am inside loop 1 & i is: 27
# I am inside loop 1 & i is: 28
# I am inside loop 1 & i is: 29
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\sumith.singh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# I am inside loop 1 & i is: 30
# I am inside loop 1 & i is: 31
# I am inside loop 1 & i is: 32
# I am inside loop 1 & i is: 33
# I am inside loop 1 & i is: 34
# I am inside loop 1 & i is: 35
# I am inside loop 1 & i is: 36
# I am inside loop 1 & i is: 37
# I am inside loop 1 & i is: 38
# I am inside loop 1 & i is: 39
# I am inside loop 1 & i is: 40
# I am inside loop 1 & i is: 41
# I am inside loop 1 & i is: 42
# I am inside loop 1 & i is: 43
# I am inside loop 1 & i is: 44
# I am inside loop 1 & i is: 45
# I am inside loop 1 & i is: 46
# I am inside loop 1 & i is: 47
# I am inside loop 1 & i is: 48
# I am inside loop 1 & i is: 49
# I am inside loop 1 & i is: 50
# I am inside loop 1 & i is: 51
# I am inside loop 1 & i is: 52
# I am inside loop 1 & i is: 53
# I am inside loop 1 & i is: 54
# I am inside loop 1 & i is: 55
# I am inside loop 1 & i is: 56
# I am inside loop 1 & i is: 57
# I am inside loop 1 & i is: 58
# I am inside loop 1 & i is: 59
# I am inside loop 1 & i is: 60
# I am inside loop 1 & i is: 61
# I am inside loop 1 & i is: 62
# I am inside loop 1 & i is: 63
# I am inside loop 1 & i is: 64
# I am inside loop 1 & i is: 65
# I am inside loop 1 & i is: 66
# I am inside loop 1 & i is: 67
# I am inside loop 1 & i is: 68
# I am inside loop 1 & i is: 69
# I am inside loop 1 & i is: 70
# I am inside loop 1 & i is: 71
# I am inside loop 1 & i is: 72
# I am inside loop 1 & i is: 73
# I am inside loop 1 & i is: 74
# I am inside loop 1 & i is: 75
# I am inside loop 1 & i is: 76
# I am inside loop 1 & i is: 77
# I am inside loop 1 & i is: 78
# I am inside loop 1 & i is: 79
# I am inside loop 1 & i is: 80
# I am inside loop 1 & i is: 81
# I am inside loop 1 & i is: 82
# I am inside loop 1 & i is: 83
# I am inside loop 1 & i is: 84
# I am inside loop 1 & i is: 85
# I am inside loop 1 & i is: 86
# I am inside loop 1 & i is: 87
# I am inside loop 1 & i is: 88
# I am inside loop 1 & i is: 89
# I am inside loop 1 & i is: 90
# I am inside loop 1 & i is: 91
# I am inside loop 1 & i is: 92
# I am inside loop 1 & i is: 93
# I am inside loop 1 & i is: 94
# I am inside loop 1 & i is: 95
# I am inside loop 1 & i is: 96
# I am inside loop 1 & i is: 97
# I am inside loop 1 & i is: 98
# I am inside loop 2 & new i is :0
# I am inside loop 2 & new i is :1
# I am inside loop 2 & new i is :2
# I am inside loop 2 & new i is :3
# I am inside loop 2 & new i is :4
# I am inside loop 2 & new i is :5
# I am inside loop 2 & new i is :6
# I am inside loop 2 & new i is :7
# I am inside loop 2 & new i is :8
# I am inside loop 2 & new i is :9
# I am inside loop 2 & new i is :10
# I am inside loop 2 & new i is :11
# I am inside loop 2 & new i is :12
# I am inside loop 2 & new i is :13
# I am inside loop 2 & new i is :14
# I am inside loop 2 & new i is :15
# I am inside loop 2 & new i is :16
# I am inside loop 2 & new i is :17
# I am inside loop 2 & new i is :18
# I am inside loop 2 & new i is :19
# I am inside loop 2 & new i is :20
# I am inside loop 2 & new i is :21
# I am inside loop 2 & new i is :22
# I am inside loop 2 & new i is :23
# I am inside loop 2 & new i is :24
# I am inside loop 2 & new i is :25
# I am inside loop 2 & new i is :26
# I am inside loop 2 & new i is :27
# I am inside loop 2 & new i is :28
# I am inside loop 2 & new i is :29
# I am inside loop 2 & new i is :30
# I am inside loop 2 & new i is :31
# I am inside loop 2 & new i is :32
# I am inside loop 2 & new i is :33
# I am inside loop 2 & new i is :34
# I am inside loop 2 & new i is :35
# I am inside loop 2 & new i is :36
# I am inside loop 2 & new i is :37
# I am inside loop 2 & new i is :38
# I am inside loop 2 & new i is :39
# I am inside loop 2 & new i is :40
# I am inside loop 2 & new i is :41
# I am inside loop 2 & new i is :42
# I am inside loop 2 & new i is :43
# I am inside loop 2 & new i is :44
# I am inside loop 2 & new i is :45
# I am inside loop 2 & new i is :46
# I am inside loop 2 & new i is :47
# I am inside loop 2 & new i is :48
# I am inside loop 2 & new i is :49
# I am inside loop 2 & new i is :50
# I am inside loop 2 & new i is :51
# I am inside loop 2 & new i is :52
# I am inside loop 2 & new i is :53
# I am inside loop 2 & new i is :54
# I am inside loop 2 & new i is :55
# I am inside loop 2 & new i is :56
# I am inside loop 2 & new i is :57
# I am inside loop 2 & new i is :58
# I am inside loop 2 & new i is :59
# I am inside loop 2 & new i is :60
# I am inside loop 2 & new i is :61
# I am inside loop 2 & new i is :62
# I am inside loop 2 & new i is :63
# I am inside loop 2 & new i is :64
# I am inside loop 2 & new i is :65
# I am inside loop 2 & new i is :66
# I am inside loop 2 & new i is :67
# I am inside loop 2 & new i is :68
# I am inside loop 2 & new i is :69
# I am inside loop 2 & new i is :70
# I am inside loop 2 & new i is :71
# I am inside loop 2 & new i is :72
# I am inside loop 2 & new i is :73
# I am inside loop 2 & new i is :74
# I am inside loop 2 & new i is :75
# I am inside loop 2 & new i is :76
# I am inside loop 2 & new i is :77
# I am inside loop 2 & new i is :78
# I am inside loop 2 & new i is :79
# I am inside loop 2 & new i is :80
# I am inside loop 2 & new i is :81
# I am inside loop 2 & new i is :82
# I am inside loop 2 & new i is :83
# I am inside loop 2 & new i is :84
# I am inside loop 2 & new i is :85
# I am inside loop 2 & new i is :86
# I am inside loop 2 & new i is :87
# I am inside loop 2 & new i is :88
# I am inside loop 2 & new i is :89
# I am inside loop 2 & new i is :90
# I am inside loop 2 & new i is :91
# I am inside loop 2 & new i is :92
# I am inside loop 2 & new i is :93
# I am inside loop 2 & new i is :94
# I am inside loop 2 & new i is :95
# I am inside loop 2 & new i is :96
# I am inside loop 2 & new i is :97
# I am inside loop 2 & new i is :98
# j is days and j is :2
# The check is from here
# j is:  0
# i is:  0
# dfx.high_nbrs[j][i] node is,  8
# The status of it 7    Not Diffused
# Name: Flag, dtype: object
# k is, check here 7    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  1
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  2
# i is:  0
# dfx.high_nbrs[j][i] node is,  63
# The status of it 62    Not Diffused
# Name: Flag, dtype: object
# k is, check here 62    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  3
# i is:  0
# dfx.high_nbrs[j][i] node is,  29
# The status of it 28    Not Diffused
# Name: Flag, dtype: object
# k is, check here 28    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  4
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  5
# i is:  0
# dfx.high_nbrs[j][i] node is,  96
# The status of it 95    Not Diffused
# Name: Flag, dtype: object
# k is, check here 95    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  6
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  7
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  8
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  9
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  10
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  11
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  12
# i is:  0
# dfx.high_nbrs[j][i] node is,  46
# The status of it 45    Not Diffused
# Name: Flag, dtype: object
# k is, check here 45    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  13
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  14
# i is:  0
# dfx.high_nbrs[j][i] node is,  33
# The status of it 32    Diffused
# Name: Flag, dtype: object
# k is, check here 32    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  15
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  16
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  17
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it 33    Not Diffused
# Name: Flag, dtype: object
# k is, check here 33    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  18
# i is:  0
# dfx.high_nbrs[j][i] node is,  8
# The status of it 7    Not Diffused
# Name: Flag, dtype: object
# k is, check here 7    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  19
# i is:  0
# dfx.high_nbrs[j][i] node is,  85
# The status of it 84    Not Diffused
# Name: Flag, dtype: object
# k is, check here 84    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  20
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it 61    Diffused
# Name: Flag, dtype: object
# k is, check here 61    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  21
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  22
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  23
# i is:  0
# dfx.high_nbrs[j][i] node is,  53
# The status of it 52    Diffused
# Name: Flag, dtype: object
# k is, check here 52    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  24
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  25
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  26
# i is:  0
# dfx.high_nbrs[j][i] node is,  81
# The status of it 80    Resitant
# Name: Flag, dtype: object
# k is, check here 80    Resitant
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  27
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  28
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  29
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  30
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it 33    Not Diffused
# Name: Flag, dtype: object
# k is, check here 33    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  31
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  32
# i is:  0
# dfx.high_nbrs[j][i] node is,  15
# The status of it 14    Not Diffused
# Name: Flag, dtype: object
# k is, check here 14    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  33
# i is:  0
# dfx.high_nbrs[j][i] node is,  18
# The status of it 17    Not Diffused
# Name: Flag, dtype: object
# k is, check here 17    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  33
# i is:  1
# dfx.high_nbrs[j][i] node is,  31
# The status of it 30    Not Diffused
# Name: Flag, dtype: object
# k is, check here 30    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  34
# i is:  0
# dfx.high_nbrs[j][i] node is,  34
# The status of it 33    Not Diffused
# Name: Flag, dtype: object
# k is, check here 33    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  35
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  36
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  37
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  38
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  39
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  40
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  41
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  42
# i is:  0
# dfx.high_nbrs[j][i] node is,  26
# The status of it 25    Not Diffused
# Name: Flag, dtype: object
# k is, check here 25    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  43
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  44
# i is:  0
# dfx.high_nbrs[j][i] node is,  72
# The status of it 71    Not Diffused
# Name: Flag, dtype: object
# k is, check here 71    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  45
# i is:  0
# dfx.high_nbrs[j][i] node is,  13
# The status of it 12    Not Diffused
# Name: Flag, dtype: object
# k is, check here 12    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  46
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  25
# The status of it 24    Not Diffused
# Name: Flag, dtype: object
# k is, check here 24    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it 61    Diffused
# Name: Flag, dtype: object
# k is, check here 61    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it 67    Not Diffused
# Name: Flag, dtype: object
# k is, check here 67    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it 76    Not Diffused
# Name: Flag, dtype: object
# k is, check here 76    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it 98    Not Diffused
# Name: Flag, dtype: object
# k is, check here 98    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it 8    Not Diffused
# Name: Flag, dtype: object
# k is, check here 8    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it 53    Not Diffused
# Name: Flag, dtype: object
# k is, check here 53    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  18
# The status of it 17    Not Diffused
# Name: Flag, dtype: object
# k is, check here 17    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it 66    Not Diffused
# Name: Flag, dtype: object
# k is, check here 66    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it 8    Not Diffused
# Name: Flag, dtype: object
# k is, check here 8    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  57
# The status of it 56    Not Diffused
# Name: Flag, dtype: object
# k is, check here 56    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  20
# The status of it 19    Diffused
# Name: Flag, dtype: object
# k is, check here 19    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  63
# The status of it 62    Not Diffused
# Name: Flag, dtype: object
# k is, check here 62    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it 30    Not Diffused
# Name: Flag, dtype: object
# k is, check here 30    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  6
# The status of it 5    Not Diffused
# Name: Flag, dtype: object
# k is, check here 5    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it 64    Not Diffused
# Name: Flag, dtype: object
# k is, check here 64    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# Till here
# I am inside loop 1 & i is: 0
# I am inside loop 1 & i is: 1
# I am inside loop 1 & i is: 2
# I am inside loop 1 & i is: 3
# I am inside loop 1 & i is: 4
# I am inside loop 1 & i is: 5
# I am inside loop 1 & i is: 6
# I am inside loop 1 & i is: 7
# I am inside loop 1 & i is: 8
# I am inside loop 1 & i is: 9
# I am inside loop 1 & i is: 10
# I am inside loop 1 & i is: 11
# I am inside loop 1 & i is: 12
# I am inside loop 1 & i is: 13
# I am inside loop 1 & i is: 14
# I am inside loop 1 & i is: 15
# I am inside loop 1 & i is: 16
# I am inside loop 1 & i is: 17
# I am inside loop 1 & i is: 18
# I am inside loop 1 & i is: 19
# I am inside loop 1 & i is: 20
# I am inside loop 1 & i is: 21
# I am inside loop 1 & i is: 22
# I am inside loop 1 & i is: 23
# I am inside loop 1 & i is: 24
# I am inside loop 1 & i is: 25
# I am inside loop 1 & i is: 26
# I am inside loop 1 & i is: 27
# I am inside loop 1 & i is: 28
# I am inside loop 1 & i is: 29
# I am inside loop 1 & i is: 30
# I am inside loop 1 & i is: 31
# I am inside loop 1 & i is: 32
# I am inside loop 1 & i is: 33
# I am inside loop 1 & i is: 34
# I am inside loop 1 & i is: 35
# I am inside loop 1 & i is: 36
# I am inside loop 1 & i is: 37
# I am inside loop 1 & i is: 38
# I am inside loop 1 & i is: 39
# I am inside loop 1 & i is: 40
# I am inside loop 1 & i is: 41
# I am inside loop 1 & i is: 42
# I am inside loop 1 & i is: 43
# I am inside loop 1 & i is: 44
# I am inside loop 1 & i is: 45
# I am inside loop 1 & i is: 46
# I am inside loop 1 & i is: 47
# I am inside loop 1 & i is: 48
# I am inside loop 1 & i is: 49
# I am inside loop 1 & i is: 50
# I am inside loop 1 & i is: 51
# I am inside loop 1 & i is: 52
# I am inside loop 1 & i is: 53
# I am inside loop 1 & i is: 54
# I am inside loop 1 & i is: 55
# I am inside loop 1 & i is: 56
# I am inside loop 1 & i is: 57
# I am inside loop 1 & i is: 58
# I am inside loop 1 & i is: 59
# I am inside loop 1 & i is: 60
# I am inside loop 1 & i is: 61
# I am inside loop 1 & i is: 62
# I am inside loop 1 & i is: 63
# I am inside loop 1 & i is: 64
# I am inside loop 1 & i is: 65
# I am inside loop 1 & i is: 66
# I am inside loop 1 & i is: 67
# I am inside loop 1 & i is: 68
# I am inside loop 1 & i is: 69
# I am inside loop 1 & i is: 70
# I am inside loop 1 & i is: 71
# I am inside loop 1 & i is: 72
# I am inside loop 1 & i is: 73
# I am inside loop 1 & i is: 74
# I am inside loop 1 & i is: 75
# I am inside loop 1 & i is: 76
# I am inside loop 1 & i is: 77
# I am inside loop 1 & i is: 78
# I am inside loop 1 & i is: 79
# I am inside loop 1 & i is: 80
# I am inside loop 1 & i is: 81
# I am inside loop 1 & i is: 82
# I am inside loop 1 & i is: 83
# I am inside loop 1 & i is: 84
# I am inside loop 1 & i is: 85
# I am inside loop 1 & i is: 86
# I am inside loop 1 & i is: 87
# I am inside loop 1 & i is: 88
# I am inside loop 1 & i is: 89
# I am inside loop 1 & i is: 90
# I am inside loop 1 & i is: 91
# I am inside loop 1 & i is: 92
# I am inside loop 1 & i is: 93
# I am inside loop 1 & i is: 94
# I am inside loop 1 & i is: 95
# I am inside loop 1 & i is: 96
# I am inside loop 1 & i is: 97
# I am inside loop 1 & i is: 98
# I am inside loop 2 & new i is :0
# I am inside loop 2 & new i is :1
# I am inside loop 2 & new i is :2
# I am inside loop 2 & new i is :3
# I am inside loop 2 & new i is :4
# I am inside loop 2 & new i is :5
# I am inside loop 2 & new i is :6
# I am inside loop 2 & new i is :7
# I am inside loop 2 & new i is :8
# I am inside loop 2 & new i is :9
# I am inside loop 2 & new i is :10
# I am inside loop 2 & new i is :11
# I am inside loop 2 & new i is :12
# I am inside loop 2 & new i is :13
# I am inside loop 2 & new i is :14
# I am inside loop 2 & new i is :15
# ...
# j is:  47
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  48
# i is:  0
# dfx.high_nbrs[j][i] node is,  25
# The status of it 24    Not Diffused
# Name: Flag, dtype: object
# k is, check here 24    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  49
# i is:  0
# dfx.high_nbrs[j][i] node is,  62
# The status of it 61    Diffused
# Name: Flag, dtype: object
# k is, check here 61    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  50
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  51
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  52
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  53
# i is:  0
# dfx.high_nbrs[j][i] node is,  68
# The status of it 67    Not Diffused
# Name: Flag, dtype: object
# k is, check here 67    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  54
# i is:  0
# dfx.high_nbrs[j][i] node is,  77
# The status of it 76    Not Diffused
# Name: Flag, dtype: object
# k is, check here 76    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  55
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  56
# i is:  0
# dfx.high_nbrs[j][i] node is,  14
# The status of it 13    Not Diffused
# Name: Flag, dtype: object
# k is, check here 13    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  57
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  58
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  59
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  60
# i is:  0
# dfx.high_nbrs[j][i] node is,  99
# The status of it 98    Not Diffused
# Name: Flag, dtype: object
# k is, check here 98    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  61
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it 8    Not Diffused
# Name: Flag, dtype: object
# k is, check here 8    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  62
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  63
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  64
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  65
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  66
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  67
# i is:  0
# dfx.high_nbrs[j][i] node is,  54
# The status of it 53    Not Diffused
# Name: Flag, dtype: object
# k is, check here 53    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  68
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  69
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  70
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  71
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  72
# i is:  0
# dfx.high_nbrs[j][i] node is,  18
# The status of it 17    Not Diffused
# Name: Flag, dtype: object
# k is, check here 17    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  73
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  74
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  75
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  76
# i is:  0
# dfx.high_nbrs[j][i] node is,  44
# The status of it 43    Not Diffused
# Name: Flag, dtype: object
# k is, check here 43    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  77
# i is:  0
# dfx.high_nbrs[j][i] node is,  67
# The status of it 66    Not Diffused
# Name: Flag, dtype: object
# k is, check here 66    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  78
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  79
# i is:  0
# dfx.high_nbrs[j][i] node is,  9
# The status of it 8    Not Diffused
# Name: Flag, dtype: object
# k is, check here 8    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  80
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  81
# i is:  0
# dfx.high_nbrs[j][i] node is,  57
# The status of it 56    Not Diffused
# Name: Flag, dtype: object
# k is, check here 56    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  82
# i is:  0
# dfx.high_nbrs[j][i] node is,  37
# The status of it 36    Not Diffused
# Name: Flag, dtype: object
# k is, check here 36    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  83
# i is:  0
# dfx.high_nbrs[j][i] node is,  38
# The status of it 37    Not Diffused
# Name: Flag, dtype: object
# k is, check here 37    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  84
# i is:  0
# dfx.high_nbrs[j][i] node is,  20
# The status of it 19    Diffused
# Name: Flag, dtype: object
# k is, check here 19    Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  85
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  86
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  87
# i is:  0
# dfx.high_nbrs[j][i] node is,  63
# The status of it 62    Not Diffused
# Name: Flag, dtype: object
# k is, check here 62    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  88
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  89
# i is:  0
# dfx.high_nbrs[j][i] node is,  56
# The status of it 55    Not Diffused
# Name: Flag, dtype: object
# k is, check here 55    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  90
# i is:  0
# dfx.high_nbrs[j][i] node is,  31
# The status of it 30    Not Diffused
# Name: Flag, dtype: object
# k is, check here 30    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  91
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  92
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  93
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  94
# i is:  0
# dfx.high_nbrs[j][i] node is,  74
# The status of it 73    Not Diffused
# Name: Flag, dtype: object
# k is, check here 73    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  95
# i is:  0
# dfx.high_nbrs[j][i] node is,  6
# The status of it 5    Not Diffused
# Name: Flag, dtype: object
# k is, check here 5    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  96
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  97
# i is:  0
# dfx.high_nbrs[j][i] node is,  65
# The status of it 64    Not Diffused
# Name: Flag, dtype: object
# k is, check here 64    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# j is:  98
# i is:  0
# dfx.high_nbrs[j][i] node is,  22
# The status of it 21    Not Diffused
# Name: Flag, dtype: object
# k is, check here 21    Not Diffused
# Name: Flag, dtype: object
# YESSSSSSS
# Till here
# I am inside loop 1 & i is: 0
# I am inside loop 1 & i is: 1
# I am inside loop 1 & i is: 2
# I am inside loop 1 & i is: 3
# I am inside loop 1 & i is: 4
# I am inside loop 1 & i is: 5
# I am inside loop 1 & i is: 6
# I am inside loop 1 & i is: 7
# I am inside loop 1 & i is: 8
# I am inside loop 1 & i is: 9
# I am inside loop 1 & i is: 10
# I am inside loop 1 & i is: 11
# I am inside loop 1 & i is: 12
# I am inside loop 1 & i is: 13
# I am inside loop 1 & i is: 14
# I am inside loop 1 & i is: 15
# I am inside loop 1 & i is: 16
# I am inside loop 1 & i is: 17
# I am inside loop 1 & i is: 18
# I am inside loop 1 & i is: 19
# I am inside loop 1 & i is: 20
# I am inside loop 1 & i is: 21
# I am inside loop 1 & i is: 22
# I am inside loop 1 & i is: 23
# I am inside loop 1 & i is: 24
# I am inside loop 1 & i is: 25
# I am inside loop 1 & i is: 26
# I am inside loop 1 & i is: 27
# I am inside loop 1 & i is: 28
# I am inside loop 1 & i is: 29
# I am inside loop 1 & i is: 30
# I am inside loop 1 & i is: 31
# I am inside loop 1 & i is: 32
# I am inside loop 1 & i is: 33
# I am inside loop 1 & i is: 34
# I am inside loop 1 & i is: 35
# I am inside loop 1 & i is: 36
# I am inside loop 1 & i is: 37
# I am inside loop 1 & i is: 38
# I am inside loop 1 & i is: 39
# I am inside loop 1 & i is: 40
# I am inside loop 1 & i is: 41
# I am inside loop 1 & i is: 42
# I am inside loop 1 & i is: 43
# I am inside loop 1 & i is: 44
# I am inside loop 1 & i is: 45
# I am inside loop 1 & i is: 46
# I am inside loop 1 & i is: 47
# I am inside loop 1 & i is: 48
# I am inside loop 1 & i is: 49
# I am inside loop 1 & i is: 50
# I am inside loop 1 & i is: 51
# I am inside loop 1 & i is: 52
# I am inside loop 1 & i is: 53
# I am inside loop 1 & i is: 54
# I am inside loop 1 & i is: 55
# I am inside loop 1 & i is: 56
# I am inside loop 1 & i is: 57
# I am inside loop 1 & i is: 58
# I am inside loop 1 & i is: 59
# I am inside loop 1 & i is: 60
# I am inside loop 1 & i is: 61
# I am inside loop 1 & i is: 62
# I am inside loop 1 & i is: 63
# I am inside loop 1 & i is: 64
# I am inside loop 1 & i is: 65
# I am inside loop 1 & i is: 66
# I am inside loop 1 & i is: 67
# I am inside loop 1 & i is: 68
# I am inside loop 1 & i is: 69
# I am inside loop 1 & i is: 70
# I am inside loop 1 & i is: 71
# I am inside loop 1 & i is: 72
# I am inside loop 1 & i is: 73
# I am inside loop 1 & i is: 74
# I am inside loop 1 & i is: 75
# I am inside loop 1 & i is: 76
# I am inside loop 1 & i is: 77
# I am inside loop 1 & i is: 78
# I am inside loop 1 & i is: 79
# I am inside loop 1 & i is: 80
# I am inside loop 1 & i is: 81
# I am inside loop 1 & i is: 82
# I am inside loop 1 & i is: 83
# I am inside loop 1 & i is: 84
# I am inside loop 1 & i is: 85
# I am inside loop 1 & i is: 86
# I am inside loop 1 & i is: 87
# I am inside loop 1 & i is: 88
# I am inside loop 1 & i is: 89
# I am inside loop 1 & i is: 90
# I am inside loop 1 & i is: 91
# I am inside loop 1 & i is: 92
# I am inside loop 1 & i is: 93
# I am inside loop 1 & i is: 94
# I am inside loop 1 & i is: 95
# I am inside loop 1 & i is: 96
# I am inside loop 1 & i is: 97
# I am inside loop 1 & i is: 98
# I am inside loop 2 & new i is :0
# I am inside loop 2 & new i is :1
# I am inside loop 2 & new i is :2
# I am inside loop 2 & new i is :3
# I am inside loop 2 & new i is :4
# I am inside loop 2 & new i is :5
# I am inside loop 2 & new i is :6
# I am inside loop 2 & new i is :7
# I am inside loop 2 & new i is :8
# I am inside loop 2 & new i is :9
# I am inside loop 2 & new i is :10
# I am inside loop 2 & new i is :11
# I am inside loop 2 & new i is :12
# I am inside loop 2 & new i is :13
# I am inside loop 2 & new i is :14
# I am inside loop 2 & new i is :15
# I am inside loop 2 & new i is :16
# I am inside loop 2 & new i is :17
# I am inside loop 2 & new i is :18
# I am inside loop 2 & new i is :19
# I am inside loop 2 & new i is :20
# I am inside loop 2 & new i is :21
# I am inside loop 2 & new i is :22
# I am inside loop 2 & new i is :23
# I am inside loop 2 & new i is :24
# I am inside loop 2 & new i is :25
# I am inside loop 2 & new i is :26
# I am inside loop 2 & new i is :27
# I am inside loop 2 & new i is :28
# I am inside loop 2 & new i is :29
# I am inside loop 2 & new i is :30
# I am inside loop 2 & new i is :31
# I am inside loop 2 & new i is :32
# I am inside loop 2 & new i is :33
# I am inside loop 2 & new i is :34
# I am inside loop 2 & new i is :35
# I am inside loop 2 & new i is :36
# I am inside loop 2 & new i is :37
# I am inside loop 2 & new i is :38
# I am inside loop 2 & new i is :39
# I am inside loop 2 & new i is :40
# I am inside loop 2 & new i is :41
# I am inside loop 2 & new i is :42
# I am inside loop 2 & new i is :43
# I am inside loop 2 & new i is :44
# I am inside loop 2 & new i is :45
# I am inside loop 2 & new i is :46
# I am inside loop 2 & new i is :47
# I am inside loop 2 & new i is :48
# I am inside loop 2 & new i is :49
# I am inside loop 2 & new i is :50
# I am inside loop 2 & new i is :51
# I am inside loop 2 & new i is :52
# I am inside loop 2 & new i is :53
# I am inside loop 2 & new i is :54
# I am inside loop 2 & new i is :55
# I am inside loop 2 & new i is :56
# I am inside loop 2 & new i is :57
# I am inside loop 2 & new i is :58
# I am inside loop 2 & new i is :59
# I am inside loop 2 & new i is :60
# I am inside loop 2 & new i is :61
# I am inside loop 2 & new i is :62
# I am inside loop 2 & new i is :63
# I am inside loop 2 & new i is :64
# I am inside loop 2 & new i is :65
# I am inside loop 2 & new i is :66
# I am inside loop 2 & new i is :67
# I am inside loop 2 & new i is :68
# I am inside loop 2 & new i is :69
# I am inside loop 2 & new i is :70
# I am inside loop 2 & new i is :71
# I am inside loop 2 & new i is :72
# I am inside loop 2 & new i is :73
# I am inside loop 2 & new i is :74
# I am inside loop 2 & new i is :75
# I am inside loop 2 & new i is :76
# I am inside loop 2 & new i is :77
# I am inside loop 2 & new i is :78
# I am inside loop 2 & new i is :79
# I am inside loop 2 & new i is :80
# I am inside loop 2 & new i is :81
# I am inside loop 2 & new i is :82
# I am inside loop 2 & new i is :83
# I am inside loop 2 & new i is :84
# I am inside loop 2 & new i is :85
# I am inside loop 2 & new i is :86
# I am inside loop 2 & new i is :87
# I am inside loop 2 & new i is :88
# I am inside loop 2 & new i is :89
# I am inside loop 2 & new i is :90
# I am inside loop 2 & new i is :91
# I am inside loop 2 & new i is :92
# I am inside loop 2 & new i is :93
# I am inside loop 2 & new i is :94
# I am inside loop 2 & new i is :95
# I am inside loop 2 & new i is :96
# I am inside loop 2 & new i is :97
# I am inside loop 2 & new i is :98
# 111.40759658813477

# %%
k = df2B_Diff_Algo2[df2B_Diff_Algo2['Node']==32]['Flag']
k
# Out:
# 31    Not Diffused
# Name: Flag, dtype: object

# %%
import time
start = time.time()
NumDays = 10
for j in (range(1, NumDays)):
    print("j is days and j is :" + str(j))
    df2C_Diff_Algo2 = realtion(df2C_Diff_Algo2)
    todivide = len(df2C_Diff_Algo2) - df2C_Diff_Algo2.knar.isnull().sum()
    df2C_Diff_Algo2['knar'] = df2C_Diff_Algo2.tcudorp[df2C_Diff_Algo2['Flag']=='Not Diffused'].rank(ascending=True)
    for i in range(len(df2C_Diff_Algo2)):
        print("I am inside loop 1 & i is: "+ str(i))
        df2C_Diff_Algo2.tcudorp[i] = df2C_Diff_Algo2.ratio[i]*df2C_Diff_Algo2.Deg_Ctrlty[i]*df2C_Diff_Algo2.Probability[i]
        df2C_Diff_Algo2.knar_norm[i] = df2C_Diff_Algo2.knar[i]/todivide
    for i in range(len(df2C_Diff_Algo2)):
        print("I am inside loop 2 & new i is :"+ str(i))
        if(df2C_Diff_Algo2.knar_norm[i]<0.15):
            print("do i ever come here? " + str(i))
            df2C_Diff_Algo2.Flag[i] = 'Diffused'
            df2C_Diff_Algo2.Day[i] = j
end = time.time()
print(end-start)

# %%
df2B_Diff_Algo2.head()

# %%
df2B_Diff_Algo2.groupby(["Flag"]).size()

# %%
df2C_Diff_Algo2.groupby(["Flag"]).size()

# %%
df2A.shape

# %% [markdown]
# ### Trimming of the Tables

# %%
df2A.sample(10)

# %%
j = 101
for i in range(len(df2C_Diff_Algo2)):
    if(df2C_Diff_Algo2.knar[i]<0.25):
        df2C_Diff_Algo2.Flag[i] = 'Diffused'
        df2C_Diff_Algo2.Day[i] = j
        
df2C_Diff_Algo2

# %%
for j in (range(1, 10)):
    print("j is days and j is :" + str(j))
    df2C_Diff_Algo2 = realtion(df2C_Diff_Algo2)
    todivide = len(df2C_Diff_Algo2) - df2C_Diff_Algo2.knar.isnull().sum()
    df2C_Diff_Algo2['knar'] = df2C_Diff_Algo2.tcudorp[df2C_Diff_Algo2['Flag']=='Not Diffused'].rank(ascending=True)
    for i in range(len(df2C_Diff_Algo2)):
        print("I am inside loop 1"+ str(i))
        df2C_Diff_Algo2.tcudorp[i] = df2C_Diff_Algo2.ratio[i]*df2C_Diff_Algo2.Deg_Ctrlty[i]*df2C_Diff_Algo2.Probability[i]
        df2C_Diff_Algo2.knar_norm[i] = df2C_Diff_Algo2.knar[i]/todivide
    for i in range(len(df2C_Diff_Algo2)):
        print("I am inside loop 2"+ str(i))
        if(df2C_Diff_Algo2.knar_norm[i]<0.25):
            print("do i ever come here? " + str(i))
            df2C_Diff_Algo2.Flag[i] = 'Diffused'
            df2C_Diff_Algo2.Day[i] = j

# %%
df2C_Diff_Algo2.sample(10)

# %%
df2A.sample(2)

# %%
df2A_trimmed = df2A
df2A_trimmed.drop(columns=['Time','min','lag','Neighbors','Deg_Cntrlty','relation','ratio'], inplace=True)
df2A_trimmed.sample(10)

# %%
df2B_Diff_Algo2_Trim = df2B_Diff_Algo2
df2B_Diff_Algo2_Trim.drop(columns=['Flag','Nbrs','Num_Nbrs','Nbrs_Dffsed','Num_Nbrs_Dffsd','Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm'], inplace=True)
df2B_Diff_Algo2_Trim.head()

# %%
df2C_Diff_Algo2_Trim = df2C_Diff_Algo2
df2C_Diff_Algo2_Trim.drop(columns=['Flag','Nbrs','Num_Nbrs','Nbrs_Dffsed','Num_Nbrs_Dffsd','Deg_Ctrlty','Probability','ratio','tcudorp','knar','knar_norm'], inplace=True)
df2C_Diff_Algo2_Trim.head()

# %%
weights = pd.read_csv("C:/Users/sumith.singh/A_SUBEX/GOF_Weight.csv", index_col=False, header=0)
TP = (weights.loc[weights['Item'] == 'TruePositive', 'Weights'])
TN = (weights.loc[weights['Item'] == 'TrueNegative', 'Weights'])
FP = (weights.loc[weights['Item'] == 'FalsePositive', 'Weights'])
FN = (weights.loc[weights['Item'] == 'FalseNegative', 'Weights'])

#print('TP: ' (TP[0]))
#print('TN: ' str(TP))
#print('FP: ' str(TP))
#print('FN: ' str(TP))
weights

# %%
# A is random Prediction
# B is actual
#C is weighted Prediction
df_GOF_BA = pd.merge(df2B_Diff_Algo2_Trim, df2A_trimmed, how='left', on=['Node'] )
df_GOF_BA['Behavior_y']=df_GOF_BA['Behavior_y'].fillna('A')
df_GOF_BA['lag2']=df_GOF_BA['lag2'].fillna(-1)
df_GOF_BA.rename(columns={'Day': 'weeks_act'}, inplace=True)
df_GOF_BA.rename(columns={'lag2': 'weeks_pred'}, inplace=True)
for i in range(len(df_GOF_BA)):
    if df_GOF_BA.weeks_act[i] == 100 :
        df_GOF_BA.weeks_act[i] = -1

for i in range(len(df_GOF_BA)):
    if df_GOF_BA.weeks_pred[i] == 100 :
        df_GOF_BA.weeks_pred[i] = -1 
        
df_GOF_BA

# %%
df_GOF_BC = pd.merge(df2B_Diff_Algo2_Trim, df2C_Diff_Algo2_Trim, how='left', on=['Node'] )
#df_GOF_BA['Behavior_y']=df_GOF_BA['Behavior_y'].fillna('A')
#df_GOF_BA['lag2']=df_GOF_BA['lag2'].fillna(-1)
df_GOF_BC.rename(columns={'Day_x': 'weeks_act'}, inplace=True)
df_GOF_BC.rename(columns={'Day_y': 'weeks_pred'}, inplace=True)
for i in range(len(df_GOF_BC)):
    if df_GOF_BC.weeks_act[i] == 100 :
        df_GOF_BC.weeks_act[i] = -1

for i in range(len(df_GOF_BC)):
    if df_GOF_BC.weeks_pred[i] == 100 :
        df_GOF_BC.weeks_pred[i] = -1        
df_GOF_BC.sample(10)

# %%
def check_overall2(df):
    if df['weeks_act'] < 0 :
        if df['weeks_pred'] < 0 :
            return 1#TN[1]
        else :
            return 1#FP[2]
    else :
        if df['weeks_pred'] >= 0 :
            return 2#TP[0]
        else :
            return 1#FN[3]

# %%
df_GOF_BC['check_numb'] = df_GOF_BC.apply(check_overall2, axis=1)

# %%
def check_overall(df):
    if df['weeks_act'] < 0 :
        if df['weeks_pred'] < 0 :
            return 'True Negative'
        else :
            return 'False Positive'
    else :
        if df['weeks_pred'] >= 0 :
            return 'True Positive'
        else :
            return 'False Negative'

# %%
df_GOF_BC['check'] = df_GOF_BC.apply(check_overall, axis=1)

# %%
def timeliness(df):
    if df['check'] == 'True Positive' :
        if df['weeks_act'] < df['weeks_pred']:
            return 'Predicted Late'
        elif df['weeks_act'] == df['weeks_pred']:
            return 'Perfect'
        else:
            return 'Predicted Early'

# %%
df_GOF_BC['Timeliness'] = df_GOF_BC.apply(timeliness, axis=1)
df_GOF_BC.sample(10)

# %%
df_GOF_BC.check_numb.sum()

# %%
df_GOF_BA['check'] = df_GOF_BA.apply(check_overall, axis=1)
df_GOF_BA['check_numb'] = df_GOF_BA.apply(check_overall2, axis=1)
df_GOF_BA.sample(10)

# %%
df_GOF_BA.check_numb.sum()

# %%
df_GOF_BA = df_GOF_BA.groupby('check').size()
df_GOF_BA

# %%
df_GOF_BA['False Positive']

# %%
df_GOF_BC = df_GOF_BC.groupby('check').size()
df_GOF_BC

# %%
TP = df_GOF_BA['True Positive']
FP = df_GOF_BA['False Positive']
FN = df_GOF_BA['False Negative']
FP = df_GOF_BA['True Negative']
x = np.array([[TP, FP], \
                [FN,FP]])

row_labels = ['P Predicted', 'N Predicted']


print ("              AP   AN ")
for row_label, row in zip(row_labels, x):
    print ('%s [%s]' % (row_label, ' '.join('%03s' % i for i in row)))

# %% [markdown]
# ## Within 2 Weeks Influencer

# %%
def realtion(dfx):
    b=[]
    for j in range(len(dfx)):
        i=0
        a=[]
        for i in range(len(dfx.Neighbors[j])):
            #print(dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values,"\t",dfx.lag2[dfx.Node==dfx.Node[j]].values)
            if dfx.lag2[dfx.Node==dfx.Neighbors[j][i]].values<dfx.lag2[dfx.Node==dfx.Node[j]].values:
                a.append(dfx.Neighbors[j][i])
        dfx['relation'][j]=a
        dfx['ratio'][j] = len(a)/len(dfx.Neighbors[j])
    return dfx

# %%
df2A.sample(2)
